# %%
import os
from google.colab import drive
import pickle
import joblib

import time
import numpy as np
import random

from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb

import tensorflow as tf
from keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import *
import cv2

# %% [markdown]
# # Data preparation

# %%
# Define the function to load images
# ...
def load_images(CURRENT, CONTENTS, CATEGORIES):
    CNT_IMG = []
    for content in CONTENTS:
        for category in CATEGORIES:
            Path = os.path.join(CURRENT, content + '-' + category)
            if not os.path.exists(Path):
                print(f"Path does not exist: {Path}")
                continue
            for i, file in enumerate(os.listdir(Path)):
                img_array = cv2.imread(os.path.join(Path, file))  # 옵션을 제거하여 컬러 이미지로 읽기
                if img_array is None:
                    print(f"Could not read image: {os.path.join(Path, file)}")
                    continue
                CNT_IMG.append([img_array, CONTENTS.index(content), CATEGORIES.index(category), file])
    return CNT_IMG

# ...


# Load data
drive.mount('/content/drive')
# CURRENT = './CNT/'
CURRENT = '/content/drive/My Drive/CNT/'  # Have to change path according to your file structure
CONTENTS = ['0','0.05', '0.1', '0.2', '0.4']  # CNT Powder Content
METHODS = ['Shear', 'Sonic']
CNT_IMG = load_images(CURRENT, CONTENTS, METHODS)
print(f"Number of images loaded: {len(CNT_IMG)}")

# %%
with open('/content/drive/My Drive/CNT_IMG_color.pkl', 'wb') as file:
    pickle.dump(CNT_IMG, file)

# %%
# Load data
drive.mount('/content/drive')
with open('/content/drive/My Drive/MSML/CNT/CNT_IMG_color.pkl', 'rb') as file:
    CNT_IMG = pickle.load(file)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Split Data

# %% [markdown]
# Divide into small sizes and split into train and test datasets

# %%
SMALL_IMG = []
# res = 0.188 # 0.188um/px
# 360.96 um x 203.04um
n_row = 3
n_col = 5
for img_array, content, method, name in CNT_IMG:
    for i in range(n_row):
        for k in range(n_col):
            height = int(img_array.shape[0]/n_row)
            width = int(img_array.shape[1]/n_col)
            small_img = img_array[i*height:(i+1)*height, k*width:(k+1)*width]
            SMALL_IMG.append([small_img, content, method, name])


labels_content = [img[1] for img in SMALL_IMG]
labels_method = [img[2] for img in SMALL_IMG]

labels_content = np.array(labels_content)
labels_method = np.array(labels_method)

# %%
# Shuffle images to be trained well
random.seed(42)
random.shuffle(SMALL_IMG)

trainN = int(len(SMALL_IMG)*0.85)
print(trainN)

Train_Data = SMALL_IMG[:trainN]
Test_Data = SMALL_IMG[trainN:]

x_train = []
y_train = []  # second label, CNT powder content
y_train_method = []


for img_array, content, label, name in Train_Data:
    x_train.append(img_array)
    y_train.append(content)
    y_train_method.append(label)

# Change List to Numpy
x_train = np.array(x_train).reshape(trainN, height, width, 3) # (instances, height, width, depth)
y_train = np.array(y_train)
y_train_method = np.array(y_train_method)

print(x_train.shape, y_train.shape, y_train_method.shape)


x_test = []
y_test = []
y_test_method = []

for img_array, content, label, name in Test_Data:
    x_test.append(img_array)
    y_test.append(content)
    y_test_method.append(label)

x_test = np.array(x_test).reshape(-1, height, width, 3)
y_test = np.array(y_test)
y_test_method = np.array(y_test_method)

print(x_test.shape, y_test.shape)
# Out:
# 4590
# (4590, 360, 384, 3) (4590,) (4590,)
# (810, 360, 384, 3) (810,)

# %% [markdown]
# ## Convert to Histogram

# %%
def compute_histogram(img, bins=256):
    # Compute histogram for each channel (R, G, B)
    hist_r = cv2.calcHist([img], [0], None, [bins], [0, 256]).flatten()
    hist_g = cv2.calcHist([img], [1], None, [bins], [0, 256]).flatten()
    hist_b = cv2.calcHist([img], [2], None, [bins], [0, 256]).flatten()
    # Stack histograms to create a "histogram image"
    hist_img = np.stack([hist_r, hist_g, hist_b], axis=-1)
    # Normalize histogram
    hist_img = hist_img / hist_img.sum()
    return hist_img

# Compute histograms for the scaled images
x_histo_train = np.array([compute_histogram(img) for img in x_train])
x_histo_test = np.array([compute_histogram(img) for img in x_test])

# %%
print(x_histo_train.shape, y_train.shape)
x_histo_train[0]
x_histo_test[0]
# Out:
# (4590, 256, 3) (4590,)
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 2.41126554e-06],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.41126554e-06, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 2.41126554e-06],
#        [0.00000000e+00, 4.82253108e-06, 7.23379617e-06],
#        [0.00000000e+00, 2.41126554e-06, 9.64506216e-06],
#        [4.82253108e-06, 0.00000000e+00, 7.23379617e-06],
#        [0.00000000e+00, 4.82253108e-06, 1.44675923e-05],
#        [7.23379617e-06, 2.41126554e-06, 2.17013894e-05],
#        [9.64506216e-06, 9.64506216e-06, 5.30478392e-05],
#        [2.41126554e-06, 1.20563273e-05, 7.23379635e-05],
#        [1.68788574e-05, 3.61689818e-05, 7.23379635e-05],
#        [1.92901243e-05, 6.99266966e-05, 1.30208340e-04],
#        [1.92901243e-05, 4.82253090e-05, 1.73611115e-04],
#        [3.13464516e-05, 9.64506180e-05, 2.45949079e-04],
#        [4.34027788e-05, 1.47087194e-04, 3.11053242e-04],
#        [8.19830238e-05, 1.80844901e-04, 4.07503860e-04],
#        [1.13329472e-04, 2.24247691e-04, 4.62962955e-04],
#        [1.13329472e-04, 2.53182865e-04, 5.90760028e-04],
#        [1.88078702e-04, 2.67650466e-04, 6.99266966e-04],
#        [2.02546289e-04, 3.44810949e-04, 7.52314809e-04],
#        [2.79706786e-04, 4.09915112e-04, 9.28337220e-04],
#        [2.86940573e-04, 4.72608022e-04, 9.42804792e-04],
#        [3.71334871e-04, 4.99131973e-04, 1.17187505e-03],
#        [4.84664342e-04, 5.81114960e-04, 1.28520443e-03],
#        [4.77430556e-04, 6.87210646e-04, 1.38888892e-03],
#        [6.14872668e-04, 7.06500781e-04, 1.72164349e-03],
#        [7.37847236e-04, 7.66782381e-04, 1.75540126e-03],
#        [8.48765427e-04, 9.57272365e-04, 2.08333344e-03],
#        [1.01514277e-03, 1.03443291e-03, 2.60657794e-03],
#        [1.21768902e-03, 1.17428624e-03, 2.94174394e-03],
#        [1.43470289e-03, 1.37683260e-03, 3.34924762e-03],
#        [1.64689426e-03, 1.51427474e-03, 4.00752295e-03],
#        [1.92177854e-03, 1.76022376e-03, 4.66097612e-03],
#        [2.30275840e-03, 1.97482645e-03, 5.28790522e-03],
#        [2.67168204e-03, 2.22318666e-03, 6.28375774e-03],
#        [3.17563652e-03, 2.55353004e-03, 7.26514263e-03],
#        [3.47945606e-03, 2.88869604e-03, 8.13319813e-03],
#        [3.89178237e-03, 3.41676315e-03, 9.43045877e-03],
#        [4.48736502e-03, 3.99305578e-03, 1.04407789e-02],
#        [4.94068302e-03, 4.70437901e-03, 1.11255785e-02],
#        [5.64718386e-03, 5.48562873e-03, 1.22926310e-02],
#        [6.36091828e-03, 6.37779711e-03, 1.29171489e-02],
#        [7.06018507e-03, 7.22173974e-03, 1.33511769e-02],
#        [7.54002715e-03, 8.06086045e-03, 1.34620946e-02],
#        [8.71431362e-03, 8.95302836e-03, 1.31775653e-02],
#        [9.35570989e-03, 9.69810970e-03, 1.25168785e-02],
#        [1.01562496e-02, 1.08555174e-02, 1.24348961e-02],
#        [1.07228970e-02, 1.14293983e-02, 1.18754823e-02],
#        [1.13980519e-02, 1.18803047e-02, 1.07566547e-02],
#        [1.14535112e-02, 1.20081017e-02, 9.91271250e-03],
#        [1.18369022e-02, 1.20322146e-02, 8.91444832e-03],
#        [1.17621524e-02, 1.20587386e-02, 8.28269683e-03],
#        [1.12919556e-02, 1.18224341e-02, 7.76668591e-03],
#        [1.10918209e-02, 1.10725304e-02, 6.81664748e-03],
#        [1.07253082e-02, 1.04600694e-02, 6.38020830e-03],
#        [1.01827737e-02, 1.01032024e-02, 5.82561735e-03],
#        [9.65229515e-03, 9.27131530e-03, 5.35542052e-03],
#        [9.00366530e-03, 8.68296716e-03, 4.68508853e-03],
#        [8.14284291e-03, 7.91136175e-03, 4.45842976e-03],
#        [7.77633116e-03, 7.55208312e-03, 4.20283573e-03],
#        [6.95650093e-03, 6.76842220e-03, 3.59760807e-03],
#        [6.85281632e-03, 6.64544757e-03, 3.36130406e-03],
#        [5.91724552e-03, 5.87384263e-03, 3.19733797e-03],
#        [5.57484571e-03, 5.30719524e-03, 2.87181721e-03],
#        [5.36024291e-03, 5.01543190e-03, 2.79465667e-03],
#        [4.83940961e-03, 4.74054785e-03, 2.59211031e-03],
#        [4.26552864e-03, 4.45601856e-03, 2.37268512e-03],
#        [4.14496521e-03, 4.10879636e-03, 2.30999221e-03],
#        [3.75916273e-03, 3.76157416e-03, 2.09780084e-03],
#        [3.58314044e-03, 3.37818288e-03, 1.93383486e-03],
#        [3.29378853e-03, 3.13705625e-03, 1.69994216e-03],
#        [3.06712952e-03, 3.07677477e-03, 1.63724925e-03],
#        [2.74160877e-03, 2.96103396e-03, 1.55526621e-03],
#        [2.59211031e-03, 2.57040886e-03, 1.49257330e-03],
#        [2.51977239e-03, 2.47636950e-03, 1.32619601e-03],
#        [2.28105718e-03, 2.37509655e-03, 1.22974534e-03],
#        [2.08092202e-03, 2.09538965e-03, 1.12364965e-03],
#        [2.02787411e-03, 2.07368820e-03, 1.06577936e-03],
#        [1.89525459e-03, 1.80844904e-03, 1.03202160e-03],
#        [1.81568286e-03, 1.80844904e-03, 8.12596467e-04],
#        [1.63483794e-03, 1.68306322e-03, 8.84934387e-04],
#        [1.58420135e-03, 1.51427474e-03, 7.81250012e-04],
#        [1.47810567e-03, 1.53356476e-03, 7.86072516e-04],
#        [1.45158183e-03, 1.31172838e-03, 7.37847236e-04],
#        [1.31172838e-03, 1.30449457e-03, 6.82388141e-04],
#        [1.29484956e-03, 1.26832561e-03, 5.76292456e-04],
#        [1.15981873e-03, 1.22733414e-03, 6.12461416e-04],
#        [1.01996528e-03, 1.12123846e-03, 5.71469893e-04],
#        [9.93441325e-04, 1.02719909e-03, 4.96720662e-04],
#        [8.84934387e-04, 9.06635774e-04, 5.61824825e-04],
#        [7.93306332e-04, 1.04407792e-03, 3.90625006e-04],
#        [8.02951399e-04, 7.95717584e-04, 4.75019304e-04],
#        [7.11323286e-04, 8.46354174e-04, 4.43672849e-04],
#        [7.71604944e-04, 8.27064039e-04, 4.29205247e-04],
#        [6.99266966e-04, 7.23379606e-04, 3.42399697e-04],
#        [6.94444461e-04, 6.70331763e-04, 3.42399697e-04],
#        [6.36574056e-04, 6.22106483e-04, 3.78568686e-04],
#        [6.38985366e-04, 5.93171280e-04, 3.03819455e-04],
#        [5.78703708e-04, 5.61824825e-04, 2.94174388e-04],
#        [5.25655865e-04, 5.18422050e-04, 3.03819455e-04],
#        [4.96720662e-04, 5.16010798e-04, 2.58005399e-04],
#        [5.57002320e-04, 4.48495382e-04, 2.60416680e-04],
#        [5.61824825e-04, 3.93036258e-04, 2.60416680e-04],
#        [4.84664342e-04, 4.31616500e-04, 2.77295534e-04],
#        [4.58140421e-04, 3.44810949e-04, 2.60416680e-04],
#        [4.02681326e-04, 4.34027781e-04, 1.71199848e-04],
#        [3.08641989e-04, 2.98996922e-04, 1.68788582e-04],
#        [3.66512337e-04, 3.64101084e-04, 2.48360331e-04],
#        [3.54456017e-04, 3.06230708e-04, 1.78433649e-04],
#        [3.13464494e-04, 2.82118068e-04, 1.56732247e-04],
#        [3.20698309e-04, 2.79706786e-04, 1.68788582e-04],
#        [3.13464494e-04, 2.89351854e-04, 1.59143514e-04],
#        [2.31481477e-04, 2.70061719e-04, 1.63966048e-04],
#        [2.55594146e-04, 2.58005399e-04, 1.61554781e-04],
#        [2.26658944e-04, 2.12191357e-04, 1.66377315e-04],
#        [2.21836424e-04, 2.19425157e-04, 1.22974539e-04],
#        [2.19425157e-04, 1.85667435e-04, 1.56732247e-04],
#        [2.09780090e-04, 1.63966048e-04, 1.18152006e-04],
#        [1.78433649e-04, 1.85667435e-04, 1.49498461e-04],
#        [1.68788582e-04, 1.78433649e-04, 1.08506945e-04],
#        [1.95312503e-04, 1.59143514e-04, 1.06095678e-04],
#        [1.35030859e-04, 1.73611115e-04, 1.27797073e-04],
#        [1.68788582e-04, 1.51909728e-04, 1.13329472e-04],
#        [1.42264660e-04, 1.20563273e-04, 1.13329472e-04],
#        [1.32619592e-04, 1.54320995e-04, 1.18152006e-04],
#        [8.43942908e-05, 1.39853393e-04, 9.88618849e-05],
#        [1.18152006e-04, 9.40393511e-05, 1.01273145e-04],
#        [7.71604973e-05, 9.88618849e-05, 8.92168246e-05],
#        [8.92168246e-05, 1.27797073e-04, 9.64506180e-05],
#        [1.10918212e-04, 8.92168246e-05, 7.95717569e-05],
#        [8.19830238e-05, 1.18152006e-04, 6.99266966e-05],
#        [9.16280842e-05, 6.99266966e-05, 7.23379635e-05],
#        [9.16280842e-05, 7.95717569e-05, 7.23379635e-05],
#        [7.95717569e-05, 1.08506945e-04, 7.95717569e-05],
#        [7.47492304e-05, 7.23379635e-05, 7.71604973e-05],
#        [7.71604973e-05, 1.20563273e-04, 9.40393511e-05],
#        [1.03684411e-04, 9.64506180e-05, 8.19830238e-05],
#        [6.02816363e-05, 9.88618849e-05, 9.40393511e-05],
#        [7.23379635e-05, 7.71604973e-05, 7.47492304e-05],
#        [8.19830238e-05, 6.26929032e-05, 9.16280842e-05],
#        [8.43942908e-05, 9.16280842e-05, 7.47492304e-05],
#        [5.54591061e-05, 6.51041701e-05, 6.26929032e-05],
#        [7.71604973e-05, 9.64506180e-05, 7.23379635e-05],
#        [7.23379635e-05, 8.19830238e-05, 6.02816363e-05],
#        [7.71604973e-05, 6.75154297e-05, 8.19830238e-05],
#        [9.64506180e-05, 9.16280842e-05, 5.30478392e-05],
#        [7.95717569e-05, 7.71604973e-05, 6.99266966e-05],
#        [1.22974539e-04, 8.68055577e-05, 1.01273145e-04],
#        [8.92168246e-05, 1.18152006e-04, 8.43942908e-05],
#        [1.20563273e-04, 9.16280842e-05, 7.71604973e-05],
#        [1.15740739e-04, 1.22974539e-04, 6.26929032e-05],
#        [9.40393511e-05, 1.42264660e-04, 5.30478392e-05],
#        [1.39853393e-04, 1.22974539e-04, 2.65239196e-05],
#        [1.08506945e-04, 1.32619592e-04, 3.37577148e-05],
#        [1.03684411e-04, 1.08506945e-04, 1.20563273e-05],
#        [1.44675927e-04, 9.40393511e-05, 2.41126545e-05],
#        [1.08506945e-04, 7.71604973e-05, 1.44675923e-05],
#        [7.23379635e-05, 6.51041701e-05, 2.41126545e-05],
#        [8.92168246e-05, 6.75154297e-05, 9.64506216e-06],
#        [7.95717569e-05, 8.43942908e-05, 4.82253108e-06],
#        [6.51041701e-05, 7.71604973e-05, 7.23379617e-06],
#        [5.30478392e-05, 3.37577148e-05, 7.23379617e-06],
#        [4.58140421e-05, 3.61689818e-05, 4.82253108e-06],
#        [3.37577148e-05, 2.41126545e-05, 2.41126554e-06],
#        [5.30478392e-05, 1.92901243e-05, 0.00000000e+00],
#        [2.65239196e-05, 1.92901243e-05, 4.82253108e-06],
#        [3.13464516e-05, 1.44675923e-05, 0.00000000e+00],
#        [2.17013894e-05, 1.68788574e-05, 0.00000000e+00],
#        [2.41126545e-05, 7.23379617e-06, 2.41126554e-06],
#        [1.92901243e-05, 7.23379617e-06, 0.00000000e+00],
#        [1.92901243e-05, 9.64506216e-06, 0.00000000e+00],
#        [7.23379617e-06, 1.44675923e-05, 0.00000000e+00],
#        [4.82253108e-06, 2.41126554e-06, 0.00000000e+00],
#        [4.82253108e-06, 7.23379617e-06, 0.00000000e+00],
#        [4.82253108e-06, 2.41126554e-06, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.41126554e-06, 2.41126554e-06, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.41126554e-06, 0.00000000e+00, 2.41126554e-06],
#        [4.82253108e-06, 0.00000000e+00, 0.00000000e+00],
#        [2.41126554e-06, 2.41126554e-06, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.41126554e-06, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]], dtype=float32)

# %%
# 채널별로 최소 및 최대값을 구합니다
min_vals = x_train.min(axis=(0,1,2), keepdims=False)
max_vals = x_train.max(axis=(0,1,2), keepdims=False)

# %%
max_vals
# Out:
# array([255, 250, 255], dtype=uint8)

# %% [markdown]
# ## Check for Robust

# %%
# Function to adjust V channel in HSV space with random adjustment
def adjust_v_channel_randomly(img):
    adjustment_value = random.randint(-5, 5)  # Random value between -10 and 10
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    v = np.clip(v + adjustment_value, 0, 255) # Adjust V channel and ensure the values are within [0, 255]

    adjusted_hsv = np.dstack((h, s, v)).astype('uint8')
    adjusted_img = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)
    return adjusted_img

# Apply random V channel adjustment to test images
x_test_adjusted_random = np.array([adjust_v_channel_randomly(img) for img in x_test])

# Compute histograms for the randomly adjusted images
x_histo_test_adjusted_random = np.array([compute_histogram(img) for img in x_test_adjusted_random])

# %%
with open('/content/drive/My Drive/x_test_adjusted_random.pkl', 'wb') as file:
    pickle.dump(x_test_adjusted_random, file)

# %% [markdown]
# ## One-hot Encoding

# %%
def to_one_hot(labels, dimension=5):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results

y_train = to_one_hot(y_train) # Transformation of train label vector
y_test = to_one_hot(y_test)   # Transformation of test label vector

# %%
x_histo = x_histo_train.reshape(x_histo_train.shape[0],-1)
x_histo_test = x_histo_test.reshape(x_histo_test.shape[0],-1)

# %% [markdown]
# # Modelling

# %% [markdown]
# ## ML

# %% [markdown]
# ### 1. KNN

# %% [markdown]
# #### GridSearch

# %%
param_grid = {
    'knn__n_neighbors': [3, 5, 7, 9, 11, 13, 15, 17],  # 이웃 수
    'knn__weights': ['uniform', 'distance'],  # 가중치 유형
    'knn__metric': ['euclidean', 'manhattan']  # 거리 측정 유형
}

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

grid_content = GridSearchCV(pipe, param_grid, cv=5)
grid_method = GridSearchCV(pipe, param_grid, cv=5)

# %%
grid_content.fit(x_histo, y_train.argmax(axis=1))
print(f"Best parameters for CONTENT: {grid_content.best_params_}")
print(f"Best cross-validation score for CONTENT: {grid_content.best_score_}")

grid_method.fit(x_histo, y_train_method)
print(f"Best parameters for METHOD: {grid_method.best_params_}")
print(f"Best cross-validation score for METHOD: {grid_method.best_score_}")

best_knn_content = grid_content.best_estimator_
best_knn_method = grid_method.best_estimator_

content_accuracy = accuracy_score(y_test.argmax(axis=1), best_knn_content.predict(x_histo_test))
method_accuracy = accuracy_score(y_test_method, best_knn_method.predict(x_histo_test))

print(f"Test accuracy for CONTENT: {content_accuracy}")
print(f"Test accuracy for METHOD: {method_accuracy}")
# Out:
# Best parameters for CONTENT: {'knn__metric': 'manhattan', 'knn__n_neighbors': 5, 'knn__weights': 'distance'}
# Best cross-validation score for CONTENT: 0.8858387799564269
# Best parameters for METHOD: {'knn__metric': 'manhattan', 'knn__n_neighbors': 7, 'knn__weights': 'uniform'}
# Best cross-validation score for METHOD: 0.9605664488017428
# Test accuracy for CONTENT: 0.8753086419753087
# Test accuracy for METHOD: 0.9604938271604938

# %% [markdown]
# #### Evaluate

# %%
joblib.dump(best_knn_content, '/content/drive/My Drive/MSML/CNT/Results/RGB/best_knn_content_model.joblib')
joblib.dump(best_knn_method, '/content/drive/My Drive/MSML/CNT/Results/RGB/best_knn_method_model.joblib')
# Out:
# ['/content/drive/My Drive/MSML/CNT/Results/RGB/best_knn_method_model.joblib']

# %%
loaded_knn_content_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_knn_content_model.joblib')
loaded_knn_method_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_knn_method_model.joblib')

loaded_content_accuracy = accuracy_score(y_test.argmax(axis=1), loaded_knn_content_model.predict(x_histo_test))
loaded_method_accuracy = accuracy_score(y_test_method, loaded_knn_method_model.predict(x_histo_test))
print(f"Test accuracy for loaded CONTENT model: {loaded_content_accuracy}")
print(f"Test accuracy for loaded METHOD model: {loaded_method_accuracy}")
# Out:
# Test accuracy for loaded CONTENT model: 0.8753086419753087
# Test accuracy for loaded METHOD model: 0.9604938271604938

# %%
y_pred_content_knn = loaded_knn_content_model.predict(x_histo_test)
y_pred_method_knn = loaded_knn_method_model.predict(x_histo_test)

print("KNN Model Metrics:")
print(f"CONTENT F1 Score: {f1_score(y_test.argmax(axis=1), y_pred_content_knn, average='macro')}")
print(f"METHOD F1 Score: {f1_score(y_test_method, y_pred_method_knn, average=None)}")
print(f"CONTENT Precision: {precision_score(y_test.argmax(axis=1), y_pred_content_knn, average='macro')}")
print(f"METHOD Precision: {precision_score(y_test_method, y_pred_method_knn, average=None)}")
print(f"CONTENT Recall: {recall_score(y_test.argmax(axis=1), y_pred_content_knn, average='macro')}")
print(f"METHOD Recall: {recall_score(y_test_method, y_pred_method_knn, average=None)}")
print(f"CONTENT Confusion Matrix:\n{confusion_matrix(y_test.argmax(axis=1), y_pred_content_knn)}")
print(f"METHOD Confusion Matrix:\n{confusion_matrix(y_test_method, y_pred_method_knn)}")
# Out:
# KNN Model Metrics:
# CONTENT F1 Score: 0.8782922032465391
# METHOD F1 Score: [0.96544276 0.95389049]
# CONTENT Precision: 0.8751234562767876
# METHOD Precision: [0.96129032 0.95942029]
# CONTENT Recall: 0.8823086555896719
# METHOD Recall: [0.96963124 0.94842407]
# CONTENT Confusion Matrix:
# [[ 88   4   3   0   0]
#  [  1 163   7   1   1]
#  [ 13  10 151  23   0]
#  [  0   0  26 139   3]
#  [  0   3   1   5 168]]
# METHOD Confusion Matrix:
# [[447  14]
#  [ 18 331]]

# %% [markdown]
# #### Plot

# %%
cm_content_knn = confusion_matrix(y_test.argmax(axis=1), y_pred_content_knn)
cm_method_knn = confusion_matrix(y_test_method, y_pred_method_knn)

cm_content_knn_norm = cm_content_knn.astype('float') / cm_content_knn.sum(axis=1)[:, np.newaxis]
cm_method_knn_norm = cm_method_knn.astype('float') / cm_method_knn.sum(axis=1)[:, np.newaxis]

fig, axs = plt.subplots(1, 2, figsize=(6.5, 3.25))

CONTENTS = [0, 0.05, 0.1, 0.2, 0.4]
METHODS = ['Shear', 'Sonic']

# KNN CONTENT 혼동 행렬을 시각화합니다.
sns.heatmap(cm_content_knn_norm, annot=True, fmt=".2f", ax=axs[0], cmap='Blues', xticklabels=CONTENTS, yticklabels=CONTENTS, vmin=0, vmax=1)
axs[0].set_title('KNN CONTENT Confusion Matrix')
axs[0].set_xlabel('Predicted')
axs[0].set_ylabel('True')

# KNN METHOD 혼동 행렬을 시각화합니다.
sns.heatmap(cm_method_knn_norm, annot=True, fmt=".2f", ax=axs[1], cmap='Blues', xticklabels=METHODS, yticklabels=METHODS, vmin=0, vmax=1)
axs[1].set_title('KNN METHOD Confusion Matrix')
axs[1].set_xlabel('Predicted')
axs[1].set_ylabel('True')

plt.tight_layout()
plt.show()

# %%
fig.savefig('/content/drive/My Drive/MSML/CNT/Results/RGB/confusion_matrix_knn.svg', format='svg')

# %% [markdown]
# ### 2. SVC

# %% [markdown]
# #### GridSearch

# %%
param_grid = {
    'svm__C': [0.1, 1, 10],  # Regularization parameter
    'svm__kernel': ['linear', 'rbf'],  # Kernel type
    'svm__gamma': ['scale', 'auto']  # Kernel coefficient for 'rbf', 'poly' and 'sigmoid'
}

pipe = Pipeline([
    ('scaler', StandardScaler()),  # 데이터 스케일링
    ('svm', SVC())  # SVM 분류기
])

grid_content = GridSearchCV(pipe, param_grid, cv=5)
grid_method = GridSearchCV(pipe, param_grid, cv=5)

# %%
grid_content.fit(x_histo, y_train.argmax(axis=1))
print(f"Best parameters for CONTENT: {grid_content.best_params_}")
print(f"Best cross-validation score for CONTENT: {grid_content.best_score_}")

grid_method.fit(x_histo, y_train_method)
print(f"Best parameters for METHOD: {grid_method.best_params_}")
print(f"Best cross-validation score for METHOD: {grid_method.best_score_}")

best_svm_content = grid_content.best_estimator_
best_svm_method = grid_method.best_estimator_

content_accuracy = accuracy_score(y_test.argmax(axis=1), best_svm_content.predict(x_histo_test))
method_accuracy = accuracy_score(y_test_method, best_svm_method.predict(x_histo_test))

print(f"Test accuracy for CONTENT: {content_accuracy}")
print(f"Test accuracy for METHOD: {method_accuracy}")

# %% [markdown]
# #### Evaluate

# %%
loaded_svm_content_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_svm_content_model.joblib')
loaded_svm_method_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_svm_method_model.joblib')

loaded_content_accuracy = accuracy_score(y_test.argmax(axis=1), loaded_svm_content_model.predict(x_histo_test))
loaded_method_accuracy = accuracy_score(y_test_method, loaded_svm_method_model.predict(x_histo_test))
print(f"Test accuracy for loaded CONTENT model: {loaded_content_accuracy}")
print(f"Test accuracy for loaded METHOD model: {loaded_method_accuracy}")
# Out:
# Test accuracy for loaded CONTENT model: 0.8938271604938272
# Test accuracy for loaded METHOD model: 0.9691358024691358

# %%
y_pred_content_svm = loaded_svm_content_model.predict(x_histo_test)
y_pred_method_svm = loaded_svm_method_model.predict(x_histo_test)

print("SVM Model Metrics:")
print(f"CONTENT F1 Score: {f1_score(y_test.argmax(axis=1), y_pred_content_svm, average='macro')}")
print(f"METHOD F1 Score: {f1_score(y_test_method, y_pred_method_svm, average=None)}")
print(f"CONTENT Precision: {precision_score(y_test.argmax(axis=1), y_pred_content_svm, average='macro')}")
print(f"METHOD Precision: {precision_score(y_test_method, y_pred_method_svm, average=None)}")
print(f"CONTENT Recall: {recall_score(y_test.argmax(axis=1), y_pred_content_svm, average='macro')}")
print(f"METHOD Recall: {recall_score(y_test_method, y_pred_method_svm, average=None)}")
print(f"CONTENT Confusion Matrix:\n{confusion_matrix(y_test.argmax(axis=1), y_pred_content_svm)}")
print(f"METHOD Confusion Matrix:\n{confusion_matrix(y_test_method, y_pred_method_svm)}")
# Out:
# SVM Model Metrics:
# CONTENT F1 Score: 0.8971616887126382
# METHOD F1 Score: [0.97291441 0.96413199]
# CONTENT Precision: 0.8929439012361357
# METHOD Precision: [0.97186147 0.96551724]
# CONTENT Recall: 0.9027607591342601
# METHOD Recall: [0.97396963 0.96275072]
# CONTENT Confusion Matrix:
# [[ 92   2   1   0   0]
#  [  2 163   5   2   1]
#  [  9  10 155  22   1]
#  [  0   0  20 140   8]
#  [  0   1   0   2 174]]
# METHOD Confusion Matrix:
# [[449  12]
#  [ 13 336]]

# %% [markdown]
# #### Plot

# %%
# 혼동 행렬을 계산합니다.
cm_content_svm = confusion_matrix(y_test.argmax(axis=1), y_pred_content_svm)
cm_method_svm = confusion_matrix(y_test_method, y_pred_method_svm)

# 혼동 행렬을 정규화합니다.
cm_content_svm_norm = cm_content_svm.astype('float') / cm_content_svm.sum(axis=1)[:, np.newaxis]
cm_method_svm_norm = cm_method_svm.astype('float') / cm_method_svm.sum(axis=1)[:, np.newaxis]

# 시각화를 위한 설정입니다.
fig, axs = plt.subplots(1, 2, figsize=(6.5, 3.25))

CONTENTS = [0, 0.05, 0.1, 0.2, 0.4]
METHODS = ['Shear', 'Sonic']

# SVM CONTENT 혼동 행렬을 시각화합니다.
sns.heatmap(cm_content_svm_norm, annot=True, fmt=".2f", ax=axs[0], cmap='Blues', xticklabels=CONTENTS, yticklabels=CONTENTS, vmin=0, vmax=1)
axs[0].set_title('SVM CONTENT Confusion Matrix')
axs[0].set_xlabel('Predicted')
axs[0].set_ylabel('True')

# SVM METHOD 혼동 행렬을 시각화합니다.
sns.heatmap(cm_method_svm_norm, annot=True, fmt=".2f", ax=axs[1], cmap='Blues', xticklabels=METHODS, yticklabels=METHODS, vmin=0, vmax=1)
axs[1].set_title('SVM METHOD Confusion Matrix')
axs[1].set_xlabel('Predicted')
axs[1].set_ylabel('True')

plt.tight_layout()
plt.show()

# %%
fig.savefig('/content/drive/My Drive/MSML/CNT/Results/RGB/confusion_matrix_svm.svg', format='svg')

# %% [markdown]
# ### 3. RF

# %% [markdown]
# Try default model

# %%
rfc_content = RandomForestClassifier(random_state=42)
rfc_method = RandomForestClassifier(random_state=42)

rfc_content.fit(x_histo, y_train.argmax(axis=1))
rfc_method.fit(x_histo, y_train_method)

content_accuracy = accuracy_score(y_test.argmax(axis=1), rfc_content.predict(x_histo_test))
method_accuracy = accuracy_score(y_test_method, rfc_method.predict(x_histo_test))

print(f"Test accuracy for CONTENT: {content_accuracy}")
print(f"Test accuracy for METHOD: {method_accuracy}")
# Out:
# Test accuracy for CONTENT: 0.9148148148148149
# Test accuracy for METHOD: 0.971604938271605

# %% [markdown]
# #### GridSearch

# %%
params = { 'n_estimators' : [100, 200],
           'max_depth' : [5, 10, 15, 20],
           'min_samples_leaf' : [4, 6, 8, 12, 16],
           'min_samples_split' : [4, 6, 8, 12, 16]
            }

grid_content = GridSearchCV(RandomForestClassifier(random_state=42), params, cv=5, n_jobs=-1)
grid_method = GridSearchCV(RandomForestClassifier(random_state=42), params, cv=5, n_jobs=-1)

# %%
grid_content.fit(x_histo, y_train.argmax(axis=1))
print(f"Best parameters for CONTENT: {grid_content.best_params_}")
print(f"Best cross-validation score for CONTENT: {grid_content.best_score_}")

grid_method.fit(x_histo, y_train_method)
print(f"Best parameters for METHOD: {grid_method.best_params_}")
print(f"Best cross-validation score for METHOD: {grid_method.best_score_}")

best_rf_content = grid_content.best_estimator_
best_rf_method = grid_method.best_estimator_

content_accuracy = accuracy_score(y_test.argmax(axis=1), best_rf_content.predict(x_histo_test))
method_accuracy = accuracy_score(y_test_method, best_rf_method.predict(x_histo_test))

print(f"Test accuracy for CONTENT: {content_accuracy}")
print(f"Test accuracy for METHOD: {method_accuracy}")
# Out:
# Best parameters for CONTENT: {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# Best cross-validation score for CONTENT: 0.9065359477124183
# Best parameters for METHOD: {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 12, 'n_estimators': 200}
# Best cross-validation score for METHOD: 0.9688453159041395
# Test accuracy for CONTENT: 0.908641975308642
# Test accuracy for METHOD: 0.9728395061728395

# %%
joblib.dump(best_rf_content, '/content/drive/My Drive/MSML/CNT/Results/RGB/best_rf_content_model.joblib')
joblib.dump(best_rf_method, '/content/drive/My Drive/MSML/CNT/Results/RGB/best_rf_method_model.joblib')
# Out:
# ['/content/drive/My Drive/MSML/CNT/Results/RGB/best_rf_method_model.joblib']

# %% [markdown]
# #### Evaluate

# %%
loaded_rf_content_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_rf_content_model.joblib')
loaded_rf_method_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_rf_method_model.joblib')

loaded_content_accuracy = accuracy_score(y_test.argmax(axis=1), loaded_rf_content_model.predict(x_histo_test))
loaded_method_accuracy = accuracy_score(y_test_method, loaded_rf_method_model.predict(x_histo_test))
print(f"Test accuracy for loaded CONTENT model: {loaded_content_accuracy}")
print(f"Test accuracy for loaded METHOD model: {loaded_method_accuracy}")
# Out:
# Test accuracy for loaded CONTENT model: 0.908641975308642
# Test accuracy for loaded METHOD model: 0.9728395061728395

# %%
y_pred_content_rf = loaded_rf_content_model.predict(x_histo_test)
y_pred_method_rf = loaded_rf_method_model.predict(x_histo_test)

print("RF Model Metrics:")
print(f"CONTENT F1 Score: {f1_score(y_test.argmax(axis=1), y_pred_content_rf, average='macro')}")
print(f"METHOD F1 Score: {f1_score(y_test_method, y_pred_method_rf, average=None)}")
print(f"CONTENT Precision: {precision_score(y_test.argmax(axis=1), y_pred_content_rf, average='macro')}")
print(f"METHOD Precision: {precision_score(y_test_method, y_pred_method_rf, average=None)}")
print(f"CONTENT Recall: {recall_score(y_test.argmax(axis=1), y_pred_content_rf, average='macro')}")
print(f"METHOD Recall: {recall_score(y_test_method, y_pred_method_rf, average=None)}")
print(f"CONTENT Confusion Matrix:\n{confusion_matrix(y_test.argmax(axis=1), y_pred_content_rf)}")
print(f"METHOD Confusion Matrix:\n{confusion_matrix(y_test_method, y_pred_method_rf)}")
# Out:
# RF Model Metrics:
# CONTENT F1 Score: 0.9151977139693237
# METHOD F1 Score: [0.97613883 0.96848138]
# CONTENT Precision: 0.9149630670882407
# METHOD Precision: [0.97613883 0.96848138]
# CONTENT Recall: 0.9155036503695662
# METHOD Recall: [0.97613883 0.96848138]
# CONTENT Confusion Matrix:
# [[ 92   2   1   0   0]
#  [  1 162   7   2   1]
#  [  2  11 164  20   0]
#  [  0   1  22 144   1]
#  [  0   1   0   2 174]]
# METHOD Confusion Matrix:
# [[450  11]
#  [ 11 338]]

# %% [markdown]
# #### Plot

# %%
# 혼동 행렬을 계산합니다.
cm_content_rf = confusion_matrix(y_test.argmax(axis=1), y_pred_content_rf)
cm_method_rf = confusion_matrix(y_test_method, y_pred_method_rf)

# 혼동 행렬을 정규화합니다.
cm_content_rf_norm = cm_content_rf.astype('float') / cm_content_rf.sum(axis=1)[:, np.newaxis]
cm_method_rf_norm = cm_method_rf.astype('float') / cm_method_rf.sum(axis=1)[:, np.newaxis]

# 시각화를 위한 설정입니다.
fig, axs = plt.subplots(1, 2, figsize=(6.5, 3.25))

CONTENTS = [0, 0.05, 0.1, 0.2, 0.4]
METHODS = ['Shear', 'Sonic']

# RF CONTENT 혼동 행렬을 시각화합니다.
sns.heatmap(cm_content_rf_norm, annot=True, fmt=".2f", ax=axs[0], cmap='Blues', xticklabels=CONTENTS, yticklabels=CONTENTS, vmin=0, vmax=1)
axs[0].set_title('RF CONTENT Confusion Matrix')
axs[0].set_xlabel('Predicted')
axs[0].set_ylabel('True')

# RF METHOD 혼동 행렬을 시각화합니다.
sns.heatmap(cm_method_rf_norm, annot=True, fmt=".2f", ax=axs[1], cmap='Blues', xticklabels=METHODS, yticklabels=METHODS, vmin=0, vmax=1)
axs[1].set_title('RF METHOD Confusion Matrix')
axs[1].set_xlabel('Predicted')
axs[1].set_ylabel('True')

plt.tight_layout()
plt.show()

# %%
fig.savefig('/content/drive/My Drive/MSML/CNT/Results/RGB/confusion_matrix_rf.svg', format='svg')

# %% [markdown]
# ### 4. LGB

# %% [markdown]
# Try default model

# %%
lgbm_content = lgb.LGBMClassifier(random_state=42)
lgbm_method = lgb.LGBMClassifier(random_state=42)

lgbm_content.fit(x_histo, y_train.argmax(axis=1))
lgbm_method.fit(x_histo, y_train_method)

content_accuracy = accuracy_score(y_test.argmax(axis=1), lgbm_content.predict(x_histo_test))
method_accuracy = accuracy_score(y_test_method, lgbm_method.predict(x_histo_test))

print(f"Test accuracy for CONTENT: {content_accuracy}")
print(f"Test accuracy for METHOD: {method_accuracy}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 121384
# [LightGBM] [Info] Number of data points in the train set: 4590, number of used features: 630
# [LightGBM] [Info] Start training from score -2.207077
# [LightGBM] [Info] Start training from score -1.497238
# [LightGBM] [Info] Start training from score -1.520885
# [LightGBM] [Info] Start training from score -1.492381
# [LightGBM] [Info] Start training from score -1.501141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2051, number of negative: 2539
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.052042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 121384
# [LightGBM] [Info] Number of data points in the train set: 4590, number of used features: 630
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.446841 -> initscore=-0.213443
# [LightGBM] [Info] Start training from score -0.213443
# Test accuracy for CONTENT: 0.9222222222222223
# Test accuracy for METHOD: 0.9765432098765432

# %% [markdown]
# #### GridSearch

# %%
params = {
    "max_depth": [25, 50, -1],
    "num_leaves": [20, 31, 40],
}

# GridSearchCV 정의
grid_content = GridSearchCV(lgb.LGBMClassifier(random_state=42, verbose=2), params, cv=3, n_jobs=-1, verbose=3)
grid_method = GridSearchCV(lgb.LGBMClassifier(random_state=42, verbose=2), params, cv=3, n_jobs=-1, verbose=3)

# %%
grid_content.fit(x_histo, y_train.argmax(axis=1))
print(f"Best parameters for CONTENT: {grid_content.best_params_}")
print(f"Best cross-validation score for CONTENT: {grid_content.best_score_}")

grid_method.fit(x_histo, y_train_method)
print(f"Best parameters for METHOD: {grid_method.best_params_}")
print(f"Best cross-validation score for METHOD: {grid_method.best_score_}")

best_lgb_content = grid_content.best_estimator_
best_lgb_method = grid_method.best_estimator_

content_accuracy = accuracy_score(y_test.argmax(axis=1), best_lgb_content.predict(x_histo_test))
method_accuracy = accuracy_score(y_test_method, best_lgb_method.predict(x_histo_test))

print(f"Test accuracy for CONTENT: {content_accuracy}")
print(f"Test accuracy for METHOD: {method_accuracy}")
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.870960
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.297307
# [LightGBM] [Debug] init for col-wise cost 0.003710 seconds, init for row-wise cost 0.021151 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046537 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 121384
# [LightGBM] [Info] Number of data points in the train set: 4590, number of used features: 630
# [LightGBM] [Info] Start training from score -2.207077
# [LightGBM] [Info] Start training from score -1.497238
# [LightGBM] [Info] Start training from score -1.520885
# [LightGBM] [Info] Start training from score -1.492381
# [LightGBM] [Info] Start training from score -1.501141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 27
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 26
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 28
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 26
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 26
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 28
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 27
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 27
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 26
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 35 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 35 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 12
# Best parameters for CONTENT: {'max_depth': 50, 'num_leaves': 40}
# Best cross-validation score for CONTENT: 0.9143790849673202
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2051, number of negative: 2539
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.870960
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.297307
# [LightGBM] [Debug] init for col-wise cost 0.003130 seconds, init for row-wise cost 0.020473 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046601 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 121384
# [LightGBM] [Info] Number of data points in the train set: 4590, number of used features: 630
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.446841 -> initscore=-0.213443
# [LightGBM] [Info] Start training from score -0.213443
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# Best parameters for METHOD: {'max_depth': 25, 'num_leaves': 31}
# Best cross-validation score for METHOD: 0.9714596949891067
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Test accuracy for CONTENT: 0.9234567901234568
# Test accuracy for METHOD: 0.9765432098765432

# %%
joblib.dump(best_lgb_content, '/content/drive/My Drive/MSML/CNT/Results/RGB/best_lgb_content_model.joblib')
joblib.dump(best_lgb_method, '/content/drive/My Drive/MSML/CNT/Results/RGB/best_lgb_method_model.joblib')
# Out:
# ['/content/drive/My Drive/MSML/CNT/Results/RGB/best_lgb_method_model.joblib']

# %% [markdown]
# #### Evaluate

# %%
lgb_content_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_lgb_content_model.joblib')
lgb_method_model = joblib.load('/content/drive/My Drive/MSML/CNT/Results/RGB/best_lgb_method_model.joblib')

content_accuracy = accuracy_score(y_test.argmax(axis=1), lgb_content_model.predict(x_histo_test))
method_accuracy = accuracy_score(y_test_method, lgb_method_model.predict(x_histo_test))
print(f"Test accuracy for loaded CONTENT model: {content_accuracy}")
print(f"Test accuracy for loaded METHOD model: {method_accuracy}")
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Test accuracy for loaded CONTENT model: 0.9234567901234568
# Test accuracy for loaded METHOD model: 0.9765432098765432

# %%
y_pred_content_lgb = lgb_content_model.predict(x_histo_test)
y_pred_method_lgb = lgb_method_model.predict(x_histo_test)

print("LGB Model Metrics:")
print(f"CONTENT F1 Score: {f1_score(y_test.argmax(axis=1), y_pred_content_lgb, average='macro')}")
print(f"METHOD F1 Score: {f1_score(y_test_method, y_pred_method_lgb, average=None)}")
print(f"CONTENT Precision: {precision_score(y_test.argmax(axis=1), y_pred_content_lgb, average='macro')}")
print(f"METHOD Precision: {precision_score(y_test_method, y_pred_method_lgb, average=None)}")
print(f"CONTENT Recall: {recall_score(y_test.argmax(axis=1), y_pred_content_lgb, average='macro')}")
print(f"METHOD Recall: {recall_score(y_test_method, y_pred_method_lgb, average=None)}")
print(f"CONTENT Confusion Matrix:\n{confusion_matrix(y_test.argmax(axis=1), y_pred_content_lgb)}")
print(f"METHOD Confusion Matrix:\n{confusion_matrix(y_test_method, y_pred_method_lgb)}")
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# LGB Model Metrics:
# CONTENT F1 Score: 0.9290602155773973
# METHOD F1 Score: [0.97950378 0.97258297]
# CONTENT Precision: 0.9294954538875512
# METHOD Precision: [0.97424893 0.97965116]
# CONTENT Recall: 0.9286690644181703
# METHOD Recall: [0.98481562 0.96561605]
# CONTENT Confusion Matrix:
# [[ 92   2   1   0   0]
#  [  0 164   6   2   1]
#  [  2   8 170  17   0]
#  [  0   1  18 148   1]
#  [  0   1   1   1 174]]
# METHOD Confusion Matrix:
# [[454   7]
#  [ 12 337]]

# %% [markdown]
# #### Plot

# %%
# 혼동 행렬을 계산합니다.
cm_content_lgb = confusion_matrix(y_test.argmax(axis=1), y_pred_content_lgb)
cm_method_lgb = confusion_matrix(y_test_method, y_pred_method_lgb)

# 혼동 행렬을 정규화합니다.
cm_content_lgb_norm = cm_content_lgb.astype('float') / cm_content_lgb.sum(axis=1)[:, np.newaxis]
cm_method_lgb_norm = cm_method_lgb.astype('float') / cm_method_lgb.sum(axis=1)[:, np.newaxis]

# 시각화를 위한 설정입니다.
fig, axs = plt.subplots(1, 2, figsize=(6.5, 3.25))

CONTENTS = [0, 0.05, 0.1, 0.2, 0.4]
METHODS = ['Shear', 'Sonic']

# LGB CONTENT 혼동 행렬을 시각화합니다.
sns.heatmap(cm_content_lgb_norm, annot=True, fmt=".2f", ax=axs[0], cmap='Blues', xticklabels=CONTENTS, yticklabels=CONTENTS, vmin=0, vmax=1)
axs[0].set_title('LGB CONTENT Confusion Matrix')
axs[0].set_xlabel('Predicted')
axs[0].set_ylabel('True')

# LGB METHOD 혼동 행렬을 시각화합니다.
sns.heatmap(cm_method_lgb_norm, annot=True, fmt=".2f", ax=axs[1], cmap='Blues', xticklabels=METHODS, yticklabels=METHODS, vmin=0, vmax=1)
axs[1].set_title('LGB METHOD Confusion Matrix')
axs[1].set_xlabel('Predicted')
axs[1].set_ylabel('True')

plt.tight_layout()
plt.show()

# %%
fig.savefig('/content/drive/My Drive/MSML/CNT/Results/RGB/confusion_matrix_lgb.svg', format='svg')

# %% [markdown]
# ## DL

# %% [markdown]
# ### CNN Layers

# %%
kernel_size = 7
# filters = [16, 32, 64]
# filters = [32, 64, 128]
filters = [64, 128, 256]

# Input Layer
input_tensor = Input(shape=(256, 3))

# Shared Layers
x = Conv1D(filters=filters[0], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(input_tensor)
x = Dropout(0.2)(x)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=filters[1], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
x = Conv1D(filters=filters[1], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
# x = Conv1D(filters=filters[1], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
# x = Dropout(0.2)(x)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=filters[2], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
x = Conv1D(filters=filters[2], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
# x = Conv1D(filters=filters[2], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
# x = Dropout(0.2)(x)
x = MaxPooling1D(pool_size=2)(x)

shared_output = Flatten()(x)

# Sonication Prediction
sonication_output = Dense(1, activation='sigmoid', name='sonication_output')(shared_output)

# Content Prediction
content_output = Dense(5, activation='softmax', name='content_output')(shared_output)

# # Construct the Model
model = Model(inputs=input_tensor, outputs=[sonication_output, content_output])

# Compile the Model
# Assuming primary focus is on 'content' prediction, we can adjust the loss weights accordingly.
WEIGHT = 0.5
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss={'sonication_output': 'binary_crossentropy', 'content_output': 'categorical_crossentropy'},
              loss_weights={'sonication_output': 1-WEIGHT, 'content_output': WEIGHT},
              metrics=['accuracy'])

model.summary()

# %% [markdown]
# ### Train

# %%
# ModelCheckpoint 콜백 설정
checkpoint_path = "/content/drive/My Drive/Results/RGB/best_cnn_model.h5"
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor="val_loss",
    verbose=1,
    save_best_only=True,
    mode='min'
)
# EarlyStopping 콜백 설정
early_stopping_callback = EarlyStopping(patience=20)

# Assuming you have corresponding labels for 'sonication' and 'content' in your dataset.
run_results = model.fit(
    x_histo_train,
    {'sonication_output': y_train_method, 'content_output': y_train},
    validation_split=0.15,
    batch_size=32,
    epochs=200,
    callbacks=[checkpoint_callback, early_stopping_callback]
)

model_path = "/content/drive/My Drive/Results/RGB/cnn_model.h5"
model.save(model_path)
print(f"Model saved at {model_path}")

model_path = "/content/drive/My Drive/Results/RGB/best_cnn_model.pkl"
with open(model_path, "wb") as file:
    pickle.dump(run_results.history, file)
# Out:
# Model: "model_24"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_25 (InputLayer)          [(None, 256, 3)]     0           []
#
#  conv1d_134 (Conv1D)            (None, 256, 64)      1408        ['input_25[0][0]']
#
#  dropout_134 (Dropout)          (None, 256, 64)      0           ['conv1d_134[0][0]']
#
#  max_pooling1d_72 (MaxPooling1D  (None, 128, 64)     0           ['dropout_134[0][0]']
#  )
#
#  conv1d_135 (Conv1D)            (None, 128, 128)     57472       ['max_pooling1d_72[0][0]']
#
#  dropout_135 (Dropout)          (None, 128, 128)     0           ['conv1d_135[0][0]']
#
#  conv1d_136 (Conv1D)            (None, 128, 128)     114816      ['dropout_135[0][0]']
#
#  dropout_136 (Dropout)          (None, 128, 128)     0           ['conv1d_136[0][0]']
#
#  max_pooling1d_73 (MaxPooling1D  (None, 64, 128)     0           ['dropout_136[0][0]']
#  )
#
#  conv1d_137 (Conv1D)            (None, 64, 256)      229632      ['max_pooling1d_73[0][0]']
#
#  dropout_137 (Dropout)          (None, 64, 256)      0           ['conv1d_137[0][0]']
#
#  conv1d_138 (Conv1D)            (None, 64, 256)      459008      ['dropout_137[0][0]']
#
#  dropout_138 (Dropout)          (None, 64, 256)      0           ['conv1d_138[0][0]']
#
#  max_pooling1d_74 (MaxPooling1D  (None, 32, 256)     0           ['dropout_138[0][0]']
#  )
#
#  flatten_24 (Flatten)           (None, 8192)         0           ['max_pooling1d_74[0][0]']
#
#  sonication_output (Dense)      (None, 1)            8193        ['flatten_24[0][0]']
#
#  content_output (Dense)         (None, 5)            40965       ['flatten_24[0][0]']
#
# ==================================================================================================
# Total params: 911,494
# Trainable params: 911,494
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# 121/122 [============================>.] - ETA: 0s - loss: 0.5498 - sonication_output_loss: 0.2842 - content_output_loss: 0.8154 - sonication_output_accuracy: 0.8776 - content_output_accuracy: 0.6219
# Epoch 1: val_loss improved from inf to 0.43235, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 7s 42ms/step - loss: 0.5493 - sonication_output_loss: 0.2848 - content_output_loss: 0.8137 - sonication_output_accuracy: 0.8775 - content_output_accuracy: 0.6224 - val_loss: 0.4324 - val_sonication_output_loss: 0.2279 - val_content_output_loss: 0.6368 - val_sonication_output_accuracy: 0.9086 - val_content_output_accuracy: 0.7518
# Epoch 2/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.3690 - sonication_output_loss: 0.1928 - content_output_loss: 0.5451 - sonication_output_accuracy: 0.9236 - content_output_accuracy: 0.7738
# Epoch 2: val_loss improved from 0.43235 to 0.36956, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 39ms/step - loss: 0.3682 - sonication_output_loss: 0.1919 - content_output_loss: 0.5446 - sonication_output_accuracy: 0.9239 - content_output_accuracy: 0.7742 - val_loss: 0.3696 - val_sonication_output_loss: 0.1903 - val_content_output_loss: 0.5488 - val_sonication_output_accuracy: 0.9318 - val_content_output_accuracy: 0.7823
# Epoch 3/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.3265 - sonication_output_loss: 0.1698 - content_output_loss: 0.4832 - sonication_output_accuracy: 0.9375 - content_output_accuracy: 0.8066
# Epoch 3: val_loss did not improve from 0.36956
# 122/122 [==============================] - 5s 38ms/step - loss: 0.3262 - sonication_output_loss: 0.1699 - content_output_loss: 0.4824 - sonication_output_accuracy: 0.9369 - content_output_accuracy: 0.8070 - val_loss: 0.3704 - val_sonication_output_loss: 0.2052 - val_content_output_loss: 0.5356 - val_sonication_output_accuracy: 0.9318 - val_content_output_accuracy: 0.7939
# Epoch 4/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.2793 - sonication_output_loss: 0.1402 - content_output_loss: 0.4185 - sonication_output_accuracy: 0.9460 - content_output_accuracy: 0.8352
# Epoch 4: val_loss improved from 0.36956 to 0.27799, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 39ms/step - loss: 0.2787 - sonication_output_loss: 0.1400 - content_output_loss: 0.4173 - sonication_output_accuracy: 0.9462 - content_output_accuracy: 0.8359 - val_loss: 0.2780 - val_sonication_output_loss: 0.1432 - val_content_output_loss: 0.4127 - val_sonication_output_accuracy: 0.9521 - val_content_output_accuracy: 0.8418
# Epoch 5/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.2554 - sonication_output_loss: 0.1303 - content_output_loss: 0.3806 - sonication_output_accuracy: 0.9507 - content_output_accuracy: 0.8487
# Epoch 5: val_loss improved from 0.27799 to 0.23897, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 39ms/step - loss: 0.2560 - sonication_output_loss: 0.1305 - content_output_loss: 0.3814 - sonication_output_accuracy: 0.9505 - content_output_accuracy: 0.8475 - val_loss: 0.2390 - val_sonication_output_loss: 0.1324 - val_content_output_loss: 0.3456 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.8839
# Epoch 6/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.2501 - sonication_output_loss: 0.1276 - content_output_loss: 0.3725 - sonication_output_accuracy: 0.9522 - content_output_accuracy: 0.8450
# Epoch 6: val_loss did not improve from 0.23897
# 122/122 [==============================] - 5s 40ms/step - loss: 0.2505 - sonication_output_loss: 0.1273 - content_output_loss: 0.3737 - sonication_output_accuracy: 0.9523 - content_output_accuracy: 0.8447 - val_loss: 0.2450 - val_sonication_output_loss: 0.1347 - val_content_output_loss: 0.3552 - val_sonication_output_accuracy: 0.9579 - val_content_output_accuracy: 0.8752
# Epoch 7/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.2101 - sonication_output_loss: 0.0979 - content_output_loss: 0.3223 - sonication_output_accuracy: 0.9607 - content_output_accuracy: 0.8753
# Epoch 7: val_loss did not improve from 0.23897
# 122/122 [==============================] - 5s 40ms/step - loss: 0.2107 - sonication_output_loss: 0.0978 - content_output_loss: 0.3237 - sonication_output_accuracy: 0.9610 - content_output_accuracy: 0.8746 - val_loss: 0.2478 - val_sonication_output_loss: 0.1286 - val_content_output_loss: 0.3670 - val_sonication_output_accuracy: 0.9536 - val_content_output_accuracy: 0.8549
# Epoch 8/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.2033 - sonication_output_loss: 0.0977 - content_output_loss: 0.3088 - sonication_output_accuracy: 0.9649 - content_output_accuracy: 0.8732
# Epoch 8: val_loss improved from 0.23897 to 0.21700, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 43ms/step - loss: 0.2040 - sonication_output_loss: 0.0980 - content_output_loss: 0.3100 - sonication_output_accuracy: 0.9649 - content_output_accuracy: 0.8729 - val_loss: 0.2170 - val_sonication_output_loss: 0.1205 - val_content_output_loss: 0.3135 - val_sonication_output_accuracy: 0.9565 - val_content_output_accuracy: 0.8853
# Epoch 9/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1911 - sonication_output_loss: 0.0935 - content_output_loss: 0.2887 - sonication_output_accuracy: 0.9615 - content_output_accuracy: 0.8820
# Epoch 9: val_loss improved from 0.21700 to 0.20581, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1930 - sonication_output_loss: 0.0945 - content_output_loss: 0.2915 - sonication_output_accuracy: 0.9608 - content_output_accuracy: 0.8803 - val_loss: 0.2058 - val_sonication_output_loss: 0.1089 - val_content_output_loss: 0.3027 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.8824
# Epoch 10/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1901 - sonication_output_loss: 0.0846 - content_output_loss: 0.2956 - sonication_output_accuracy: 0.9693 - content_output_accuracy: 0.8747
# Epoch 10: val_loss did not improve from 0.20581
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1897 - sonication_output_loss: 0.0846 - content_output_loss: 0.2949 - sonication_output_accuracy: 0.9695 - content_output_accuracy: 0.8749 - val_loss: 0.2451 - val_sonication_output_loss: 0.1302 - val_content_output_loss: 0.3599 - val_sonication_output_accuracy: 0.9608 - val_content_output_accuracy: 0.8708
# Epoch 11/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1951 - sonication_output_loss: 0.0909 - content_output_loss: 0.2993 - sonication_output_accuracy: 0.9638 - content_output_accuracy: 0.8789
# Epoch 11: val_loss improved from 0.20581 to 0.19929, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 41ms/step - loss: 0.1951 - sonication_output_loss: 0.0910 - content_output_loss: 0.2992 - sonication_output_accuracy: 0.9636 - content_output_accuracy: 0.8790 - val_loss: 0.1993 - val_sonication_output_loss: 0.1155 - val_content_output_loss: 0.2831 - val_sonication_output_accuracy: 0.9608 - val_content_output_accuracy: 0.8911
# Epoch 12/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1721 - sonication_output_loss: 0.0823 - content_output_loss: 0.2620 - sonication_output_accuracy: 0.9682 - content_output_accuracy: 0.8939
# Epoch 12: val_loss improved from 0.19929 to 0.19664, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1723 - sonication_output_loss: 0.0825 - content_output_loss: 0.2621 - sonication_output_accuracy: 0.9680 - content_output_accuracy: 0.8936 - val_loss: 0.1966 - val_sonication_output_loss: 0.1113 - val_content_output_loss: 0.2819 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.8984
# Epoch 13/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1706 - sonication_output_loss: 0.0803 - content_output_loss: 0.2609 - sonication_output_accuracy: 0.9688 - content_output_accuracy: 0.8931
# Epoch 13: val_loss did not improve from 0.19664
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1700 - sonication_output_loss: 0.0800 - content_output_loss: 0.2601 - sonication_output_accuracy: 0.9690 - content_output_accuracy: 0.8936 - val_loss: 0.2055 - val_sonication_output_loss: 0.1137 - val_content_output_loss: 0.2973 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.8882
# Epoch 14/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1675 - sonication_output_loss: 0.0781 - content_output_loss: 0.2570 - sonication_output_accuracy: 0.9716 - content_output_accuracy: 0.8944
# Epoch 14: val_loss improved from 0.19664 to 0.18513, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 43ms/step - loss: 0.1677 - sonication_output_loss: 0.0784 - content_output_loss: 0.2570 - sonication_output_accuracy: 0.9715 - content_output_accuracy: 0.8939 - val_loss: 0.1851 - val_sonication_output_loss: 0.1063 - val_content_output_loss: 0.2640 - val_sonication_output_accuracy: 0.9652 - val_content_output_accuracy: 0.9071
# Epoch 15/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1710 - sonication_output_loss: 0.0799 - content_output_loss: 0.2622 - sonication_output_accuracy: 0.9685 - content_output_accuracy: 0.8910
# Epoch 15: val_loss did not improve from 0.18513
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1704 - sonication_output_loss: 0.0796 - content_output_loss: 0.2611 - sonication_output_accuracy: 0.9687 - content_output_accuracy: 0.8916 - val_loss: 0.2011 - val_sonication_output_loss: 0.1096 - val_content_output_loss: 0.2926 - val_sonication_output_accuracy: 0.9623 - val_content_output_accuracy: 0.9086
# Epoch 16/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1746 - sonication_output_loss: 0.0825 - content_output_loss: 0.2668 - sonication_output_accuracy: 0.9706 - content_output_accuracy: 0.8936
# Epoch 16: val_loss did not improve from 0.18513
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1738 - sonication_output_loss: 0.0821 - content_output_loss: 0.2656 - sonication_output_accuracy: 0.9708 - content_output_accuracy: 0.8941 - val_loss: 0.2169 - val_sonication_output_loss: 0.1159 - val_content_output_loss: 0.3178 - val_sonication_output_accuracy: 0.9608 - val_content_output_accuracy: 0.8810
# Epoch 17/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1602 - sonication_output_loss: 0.0719 - content_output_loss: 0.2485 - sonication_output_accuracy: 0.9726 - content_output_accuracy: 0.8970
# Epoch 17: val_loss did not improve from 0.18513
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1603 - sonication_output_loss: 0.0721 - content_output_loss: 0.2485 - sonication_output_accuracy: 0.9726 - content_output_accuracy: 0.8969 - val_loss: 0.1853 - val_sonication_output_loss: 0.1208 - val_content_output_loss: 0.2497 - val_sonication_output_accuracy: 0.9565 - val_content_output_accuracy: 0.8970
# Epoch 18/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1601 - sonication_output_loss: 0.0768 - content_output_loss: 0.2434 - sonication_output_accuracy: 0.9700 - content_output_accuracy: 0.9019
# Epoch 18: val_loss did not improve from 0.18513
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1597 - sonication_output_loss: 0.0764 - content_output_loss: 0.2430 - sonication_output_accuracy: 0.9703 - content_output_accuracy: 0.9021 - val_loss: 0.1927 - val_sonication_output_loss: 0.0954 - val_content_output_loss: 0.2900 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.8897
# Epoch 19/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1629 - sonication_output_loss: 0.0726 - content_output_loss: 0.2532 - sonication_output_accuracy: 0.9724 - content_output_accuracy: 0.8975
# Epoch 19: val_loss did not improve from 0.18513
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1625 - sonication_output_loss: 0.0725 - content_output_loss: 0.2525 - sonication_output_accuracy: 0.9723 - content_output_accuracy: 0.8975 - val_loss: 0.1896 - val_sonication_output_loss: 0.1069 - val_content_output_loss: 0.2722 - val_sonication_output_accuracy: 0.9652 - val_content_output_accuracy: 0.9028
# Epoch 20/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1571 - sonication_output_loss: 0.0699 - content_output_loss: 0.2443 - sonication_output_accuracy: 0.9742 - content_output_accuracy: 0.9016
# Epoch 20: val_loss improved from 0.18513 to 0.18410, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 41ms/step - loss: 0.1572 - sonication_output_loss: 0.0696 - content_output_loss: 0.2447 - sonication_output_accuracy: 0.9744 - content_output_accuracy: 0.9011 - val_loss: 0.1841 - val_sonication_output_loss: 0.0970 - val_content_output_loss: 0.2712 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.8868
# Epoch 21/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1496 - sonication_output_loss: 0.0671 - content_output_loss: 0.2321 - sonication_output_accuracy: 0.9724 - content_output_accuracy: 0.9052
# Epoch 21: val_loss did not improve from 0.18410
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1495 - sonication_output_loss: 0.0669 - content_output_loss: 0.2322 - sonication_output_accuracy: 0.9726 - content_output_accuracy: 0.9052 - val_loss: 0.1966 - val_sonication_output_loss: 0.1144 - val_content_output_loss: 0.2789 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.8940
# Epoch 22/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1455 - sonication_output_loss: 0.0667 - content_output_loss: 0.2242 - sonication_output_accuracy: 0.9755 - content_output_accuracy: 0.9062
# Epoch 22: val_loss did not improve from 0.18410
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1457 - sonication_output_loss: 0.0671 - content_output_loss: 0.2243 - sonication_output_accuracy: 0.9751 - content_output_accuracy: 0.9062 - val_loss: 0.1941 - val_sonication_output_loss: 0.1139 - val_content_output_loss: 0.2743 - val_sonication_output_accuracy: 0.9565 - val_content_output_accuracy: 0.8911
# Epoch 23/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1445 - sonication_output_loss: 0.0622 - content_output_loss: 0.2269 - sonication_output_accuracy: 0.9770 - content_output_accuracy: 0.9055
# Epoch 23: val_loss did not improve from 0.18410
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1447 - sonication_output_loss: 0.0628 - content_output_loss: 0.2266 - sonication_output_accuracy: 0.9769 - content_output_accuracy: 0.9057 - val_loss: 0.2139 - val_sonication_output_loss: 0.1205 - val_content_output_loss: 0.3072 - val_sonication_output_accuracy: 0.9565 - val_content_output_accuracy: 0.8723
# Epoch 24/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1461 - sonication_output_loss: 0.0684 - content_output_loss: 0.2238 - sonication_output_accuracy: 0.9729 - content_output_accuracy: 0.9122
# Epoch 24: val_loss improved from 0.18410 to 0.16688, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 43ms/step - loss: 0.1458 - sonication_output_loss: 0.0684 - content_output_loss: 0.2232 - sonication_output_accuracy: 0.9728 - content_output_accuracy: 0.9123 - val_loss: 0.1669 - val_sonication_output_loss: 0.1008 - val_content_output_loss: 0.2329 - val_sonication_output_accuracy: 0.9652 - val_content_output_accuracy: 0.9013
# Epoch 25/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1382 - sonication_output_loss: 0.0639 - content_output_loss: 0.2124 - sonication_output_accuracy: 0.9760 - content_output_accuracy: 0.9119
# Epoch 25: val_loss did not improve from 0.16688
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1382 - sonication_output_loss: 0.0639 - content_output_loss: 0.2124 - sonication_output_accuracy: 0.9759 - content_output_accuracy: 0.9121 - val_loss: 0.1777 - val_sonication_output_loss: 0.0955 - val_content_output_loss: 0.2599 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.9042
# Epoch 26/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1455 - sonication_output_loss: 0.0647 - content_output_loss: 0.2263 - sonication_output_accuracy: 0.9765 - content_output_accuracy: 0.9081
# Epoch 26: val_loss did not improve from 0.16688
# 122/122 [==============================] - 5s 37ms/step - loss: 0.1449 - sonication_output_loss: 0.0643 - content_output_loss: 0.2254 - sonication_output_accuracy: 0.9767 - content_output_accuracy: 0.9082 - val_loss: 0.1982 - val_sonication_output_loss: 0.1042 - val_content_output_loss: 0.2923 - val_sonication_output_accuracy: 0.9652 - val_content_output_accuracy: 0.8795
# Epoch 27/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1536 - sonication_output_loss: 0.0676 - content_output_loss: 0.2396 - sonication_output_accuracy: 0.9739 - content_output_accuracy: 0.9070
# Epoch 27: val_loss did not improve from 0.16688
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1537 - sonication_output_loss: 0.0674 - content_output_loss: 0.2400 - sonication_output_accuracy: 0.9741 - content_output_accuracy: 0.9067 - val_loss: 0.1880 - val_sonication_output_loss: 0.1130 - val_content_output_loss: 0.2630 - val_sonication_output_accuracy: 0.9594 - val_content_output_accuracy: 0.8999
# Epoch 28/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1325 - sonication_output_loss: 0.0596 - content_output_loss: 0.2055 - sonication_output_accuracy: 0.9760 - content_output_accuracy: 0.9143
# Epoch 28: val_loss did not improve from 0.16688
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1323 - sonication_output_loss: 0.0596 - content_output_loss: 0.2049 - sonication_output_accuracy: 0.9762 - content_output_accuracy: 0.9141 - val_loss: 0.1703 - val_sonication_output_loss: 0.0986 - val_content_output_loss: 0.2421 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9057
# Epoch 29/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1323 - sonication_output_loss: 0.0596 - content_output_loss: 0.2050 - sonication_output_accuracy: 0.9765 - content_output_accuracy: 0.9153
# Epoch 29: val_loss improved from 0.16688 to 0.15804, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 43ms/step - loss: 0.1327 - sonication_output_loss: 0.0598 - content_output_loss: 0.2056 - sonication_output_accuracy: 0.9762 - content_output_accuracy: 0.9149 - val_loss: 0.1580 - val_sonication_output_loss: 0.0980 - val_content_output_loss: 0.2181 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.9129
# Epoch 30/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1290 - sonication_output_loss: 0.0606 - content_output_loss: 0.1974 - sonication_output_accuracy: 0.9775 - content_output_accuracy: 0.9176
# Epoch 30: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1288 - sonication_output_loss: 0.0605 - content_output_loss: 0.1971 - sonication_output_accuracy: 0.9774 - content_output_accuracy: 0.9177 - val_loss: 0.1987 - val_sonication_output_loss: 0.1021 - val_content_output_loss: 0.2953 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.8737
# Epoch 31/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1495 - sonication_output_loss: 0.0679 - content_output_loss: 0.2311 - sonication_output_accuracy: 0.9731 - content_output_accuracy: 0.9068
# Epoch 31: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1494 - sonication_output_loss: 0.0681 - content_output_loss: 0.2307 - sonication_output_accuracy: 0.9731 - content_output_accuracy: 0.9069 - val_loss: 0.1748 - val_sonication_output_loss: 0.1076 - val_content_output_loss: 0.2420 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9100
# Epoch 32/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1315 - sonication_output_loss: 0.0575 - content_output_loss: 0.2056 - sonication_output_accuracy: 0.9775 - content_output_accuracy: 0.9143
# Epoch 32: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1316 - sonication_output_loss: 0.0574 - content_output_loss: 0.2057 - sonication_output_accuracy: 0.9777 - content_output_accuracy: 0.9141 - val_loss: 0.2054 - val_sonication_output_loss: 0.1214 - val_content_output_loss: 0.2894 - val_sonication_output_accuracy: 0.9579 - val_content_output_accuracy: 0.8868
# Epoch 33/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1271 - sonication_output_loss: 0.0567 - content_output_loss: 0.1975 - sonication_output_accuracy: 0.9806 - content_output_accuracy: 0.9192
# Epoch 33: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 41ms/step - loss: 0.1270 - sonication_output_loss: 0.0567 - content_output_loss: 0.1973 - sonication_output_accuracy: 0.9808 - content_output_accuracy: 0.9193 - val_loss: 0.1872 - val_sonication_output_loss: 0.1049 - val_content_output_loss: 0.2694 - val_sonication_output_accuracy: 0.9652 - val_content_output_accuracy: 0.9013
# Epoch 34/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1347 - sonication_output_loss: 0.0620 - content_output_loss: 0.2073 - sonication_output_accuracy: 0.9765 - content_output_accuracy: 0.9140
# Epoch 34: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 41ms/step - loss: 0.1346 - sonication_output_loss: 0.0624 - content_output_loss: 0.2067 - sonication_output_accuracy: 0.9764 - content_output_accuracy: 0.9144 - val_loss: 0.1709 - val_sonication_output_loss: 0.1037 - val_content_output_loss: 0.2380 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.8926
# Epoch 35/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1234 - sonication_output_loss: 0.0592 - content_output_loss: 0.1876 - sonication_output_accuracy: 0.9773 - content_output_accuracy: 0.9256
# Epoch 35: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1234 - sonication_output_loss: 0.0589 - content_output_loss: 0.1879 - sonication_output_accuracy: 0.9774 - content_output_accuracy: 0.9254 - val_loss: 0.1583 - val_sonication_output_loss: 0.1008 - val_content_output_loss: 0.2158 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.9173
# Epoch 36/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1297 - sonication_output_loss: 0.0592 - content_output_loss: 0.2001 - sonication_output_accuracy: 0.9788 - content_output_accuracy: 0.9194
# Epoch 36: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1303 - sonication_output_loss: 0.0599 - content_output_loss: 0.2008 - sonication_output_accuracy: 0.9785 - content_output_accuracy: 0.9193 - val_loss: 0.1638 - val_sonication_output_loss: 0.0942 - val_content_output_loss: 0.2334 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.9042
# Epoch 37/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1210 - sonication_output_loss: 0.0578 - content_output_loss: 0.1842 - sonication_output_accuracy: 0.9765 - content_output_accuracy: 0.9277
# Epoch 37: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1208 - sonication_output_loss: 0.0581 - content_output_loss: 0.1835 - sonication_output_accuracy: 0.9764 - content_output_accuracy: 0.9277 - val_loss: 0.1725 - val_sonication_output_loss: 0.1044 - val_content_output_loss: 0.2406 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9028
# Epoch 38/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1263 - sonication_output_loss: 0.0537 - content_output_loss: 0.1990 - sonication_output_accuracy: 0.9786 - content_output_accuracy: 0.9197
# Epoch 38: val_loss did not improve from 0.15804
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1258 - sonication_output_loss: 0.0533 - content_output_loss: 0.1983 - sonication_output_accuracy: 0.9787 - content_output_accuracy: 0.9198 - val_loss: 0.1769 - val_sonication_output_loss: 0.0941 - val_content_output_loss: 0.2597 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.8868
# Epoch 39/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1286 - sonication_output_loss: 0.0585 - content_output_loss: 0.1987 - sonication_output_accuracy: 0.9762 - content_output_accuracy: 0.9241
# Epoch 39: val_loss improved from 0.15804 to 0.15314, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 42ms/step - loss: 0.1282 - sonication_output_loss: 0.0581 - content_output_loss: 0.1983 - sonication_output_accuracy: 0.9764 - content_output_accuracy: 0.9241 - val_loss: 0.1531 - val_sonication_output_loss: 0.0916 - val_content_output_loss: 0.2147 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.9158
# Epoch 40/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1162 - sonication_output_loss: 0.0525 - content_output_loss: 0.1799 - sonication_output_accuracy: 0.9811 - content_output_accuracy: 0.9282
# Epoch 40: val_loss improved from 0.15314 to 0.15237, saving model to /content/drive/My Drive/Results/RGB/best_cnn_model.h5
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1160 - sonication_output_loss: 0.0523 - content_output_loss: 0.1797 - sonication_output_accuracy: 0.9813 - content_output_accuracy: 0.9280 - val_loss: 0.1524 - val_sonication_output_loss: 0.0935 - val_content_output_loss: 0.2113 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.9057
# Epoch 41/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1234 - sonication_output_loss: 0.0581 - content_output_loss: 0.1887 - sonication_output_accuracy: 0.9770 - content_output_accuracy: 0.9238
# Epoch 41: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 37ms/step - loss: 0.1235 - sonication_output_loss: 0.0580 - content_output_loss: 0.1890 - sonication_output_accuracy: 0.9769 - content_output_accuracy: 0.9236 - val_loss: 0.1587 - val_sonication_output_loss: 0.0898 - val_content_output_loss: 0.2277 - val_sonication_output_accuracy: 0.9695 - val_content_output_accuracy: 0.9187
# Epoch 42/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1162 - sonication_output_loss: 0.0526 - content_output_loss: 0.1797 - sonication_output_accuracy: 0.9788 - content_output_accuracy: 0.9279
# Epoch 42: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 37ms/step - loss: 0.1166 - sonication_output_loss: 0.0526 - content_output_loss: 0.1806 - sonication_output_accuracy: 0.9790 - content_output_accuracy: 0.9277 - val_loss: 0.1653 - val_sonication_output_loss: 0.1091 - val_content_output_loss: 0.2215 - val_sonication_output_accuracy: 0.9608 - val_content_output_accuracy: 0.9042
# Epoch 43/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1089 - sonication_output_loss: 0.0468 - content_output_loss: 0.1710 - sonication_output_accuracy: 0.9814 - content_output_accuracy: 0.9295
# Epoch 43: val_loss did not improve from 0.15237
# 122/122 [==============================] - 4s 37ms/step - loss: 0.1087 - sonication_output_loss: 0.0468 - content_output_loss: 0.1706 - sonication_output_accuracy: 0.9813 - content_output_accuracy: 0.9292 - val_loss: 0.1679 - val_sonication_output_loss: 0.1026 - val_content_output_loss: 0.2332 - val_sonication_output_accuracy: 0.9637 - val_content_output_accuracy: 0.9057
# Epoch 44/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1029 - sonication_output_loss: 0.0453 - content_output_loss: 0.1606 - sonication_output_accuracy: 0.9824 - content_output_accuracy: 0.9365
# Epoch 44: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 37ms/step - loss: 0.1029 - sonication_output_loss: 0.0451 - content_output_loss: 0.1607 - sonication_output_accuracy: 0.9826 - content_output_accuracy: 0.9362 - val_loss: 0.1618 - val_sonication_output_loss: 0.1037 - val_content_output_loss: 0.2199 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9187
# Epoch 45/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1112 - sonication_output_loss: 0.0483 - content_output_loss: 0.1740 - sonication_output_accuracy: 0.9832 - content_output_accuracy: 0.9326
# Epoch 45: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1112 - sonication_output_loss: 0.0484 - content_output_loss: 0.1740 - sonication_output_accuracy: 0.9831 - content_output_accuracy: 0.9323 - val_loss: 0.1947 - val_sonication_output_loss: 0.1110 - val_content_output_loss: 0.2784 - val_sonication_output_accuracy: 0.9565 - val_content_output_accuracy: 0.8853
# Epoch 46/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1088 - sonication_output_loss: 0.0466 - content_output_loss: 0.1710 - sonication_output_accuracy: 0.9824 - content_output_accuracy: 0.9313
# Epoch 46: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1090 - sonication_output_loss: 0.0466 - content_output_loss: 0.1714 - sonication_output_accuracy: 0.9826 - content_output_accuracy: 0.9313 - val_loss: 0.1819 - val_sonication_output_loss: 0.1169 - val_content_output_loss: 0.2468 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.8940
# Epoch 47/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1000 - sonication_output_loss: 0.0469 - content_output_loss: 0.1530 - sonication_output_accuracy: 0.9811 - content_output_accuracy: 0.9380
# Epoch 47: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1004 - sonication_output_loss: 0.0469 - content_output_loss: 0.1538 - sonication_output_accuracy: 0.9810 - content_output_accuracy: 0.9377 - val_loss: 0.1611 - val_sonication_output_loss: 0.1001 - val_content_output_loss: 0.2221 - val_sonication_output_accuracy: 0.9695 - val_content_output_accuracy: 0.9158
# Epoch 48/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1125 - sonication_output_loss: 0.0545 - content_output_loss: 0.1705 - sonication_output_accuracy: 0.9778 - content_output_accuracy: 0.9321
# Epoch 48: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1123 - sonication_output_loss: 0.0545 - content_output_loss: 0.1701 - sonication_output_accuracy: 0.9777 - content_output_accuracy: 0.9323 - val_loss: 0.1605 - val_sonication_output_loss: 0.0946 - val_content_output_loss: 0.2264 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9158
# Epoch 49/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.0991 - sonication_output_loss: 0.0435 - content_output_loss: 0.1546 - sonication_output_accuracy: 0.9817 - content_output_accuracy: 0.9362
# Epoch 49: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.0990 - sonication_output_loss: 0.0440 - content_output_loss: 0.1540 - sonication_output_accuracy: 0.9815 - content_output_accuracy: 0.9364 - val_loss: 0.1689 - val_sonication_output_loss: 0.1004 - val_content_output_loss: 0.2375 - val_sonication_output_accuracy: 0.9695 - val_content_output_accuracy: 0.8999
# Epoch 50/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1098 - sonication_output_loss: 0.0464 - content_output_loss: 0.1732 - sonication_output_accuracy: 0.9832 - content_output_accuracy: 0.9282
# Epoch 50: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1095 - sonication_output_loss: 0.0463 - content_output_loss: 0.1727 - sonication_output_accuracy: 0.9833 - content_output_accuracy: 0.9282 - val_loss: 0.1633 - val_sonication_output_loss: 0.0958 - val_content_output_loss: 0.2307 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9129
# Epoch 51/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1039 - sonication_output_loss: 0.0430 - content_output_loss: 0.1647 - sonication_output_accuracy: 0.9845 - content_output_accuracy: 0.9331
# Epoch 51: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1037 - sonication_output_loss: 0.0429 - content_output_loss: 0.1645 - sonication_output_accuracy: 0.9846 - content_output_accuracy: 0.9331 - val_loss: 0.1605 - val_sonication_output_loss: 0.0922 - val_content_output_loss: 0.2288 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9042
# Epoch 52/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.0991 - sonication_output_loss: 0.0422 - content_output_loss: 0.1560 - sonication_output_accuracy: 0.9840 - content_output_accuracy: 0.9357
# Epoch 52: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 40ms/step - loss: 0.1003 - sonication_output_loss: 0.0431 - content_output_loss: 0.1575 - sonication_output_accuracy: 0.9839 - content_output_accuracy: 0.9351 - val_loss: 0.1921 - val_sonication_output_loss: 0.1051 - val_content_output_loss: 0.2791 - val_sonication_output_accuracy: 0.9536 - val_content_output_accuracy: 0.8839
# Epoch 53/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.0969 - sonication_output_loss: 0.0436 - content_output_loss: 0.1502 - sonication_output_accuracy: 0.9835 - content_output_accuracy: 0.9409
# Epoch 53: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 39ms/step - loss: 0.0984 - sonication_output_loss: 0.0445 - content_output_loss: 0.1524 - sonication_output_accuracy: 0.9833 - content_output_accuracy: 0.9405 - val_loss: 0.1701 - val_sonication_output_loss: 0.0927 - val_content_output_loss: 0.2476 - val_sonication_output_accuracy: 0.9710 - val_content_output_accuracy: 0.8955
# Epoch 54/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1023 - sonication_output_loss: 0.0442 - content_output_loss: 0.1603 - sonication_output_accuracy: 0.9842 - content_output_accuracy: 0.9336
# Epoch 54: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 39ms/step - loss: 0.1025 - sonication_output_loss: 0.0440 - content_output_loss: 0.1609 - sonication_output_accuracy: 0.9844 - content_output_accuracy: 0.9339 - val_loss: 0.1581 - val_sonication_output_loss: 0.0914 - val_content_output_loss: 0.2248 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.9144
# Epoch 55/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.0987 - sonication_output_loss: 0.0367 - content_output_loss: 0.1608 - sonication_output_accuracy: 0.9863 - content_output_accuracy: 0.9341
# Epoch 55: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.0986 - sonication_output_loss: 0.0365 - content_output_loss: 0.1606 - sonication_output_accuracy: 0.9864 - content_output_accuracy: 0.9339 - val_loss: 0.1554 - val_sonication_output_loss: 0.0872 - val_content_output_loss: 0.2236 - val_sonication_output_accuracy: 0.9710 - val_content_output_accuracy: 0.9216
# Epoch 56/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.0938 - sonication_output_loss: 0.0446 - content_output_loss: 0.1430 - sonication_output_accuracy: 0.9819 - content_output_accuracy: 0.9416
# Epoch 56: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.0934 - sonication_output_loss: 0.0443 - content_output_loss: 0.1425 - sonication_output_accuracy: 0.9821 - content_output_accuracy: 0.9418 - val_loss: 0.1806 - val_sonication_output_loss: 0.1090 - val_content_output_loss: 0.2523 - val_sonication_output_accuracy: 0.9623 - val_content_output_accuracy: 0.8984
# Epoch 57/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1048 - sonication_output_loss: 0.0506 - content_output_loss: 0.1590 - sonication_output_accuracy: 0.9804 - content_output_accuracy: 0.9344
# Epoch 57: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.1045 - sonication_output_loss: 0.0506 - content_output_loss: 0.1584 - sonication_output_accuracy: 0.9803 - content_output_accuracy: 0.9346 - val_loss: 0.1619 - val_sonication_output_loss: 0.0802 - val_content_output_loss: 0.2436 - val_sonication_output_accuracy: 0.9710 - val_content_output_accuracy: 0.9086
# Epoch 58/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.0840 - sonication_output_loss: 0.0354 - content_output_loss: 0.1326 - sonication_output_accuracy: 0.9868 - content_output_accuracy: 0.9442
# Epoch 58: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 38ms/step - loss: 0.0836 - sonication_output_loss: 0.0352 - content_output_loss: 0.1319 - sonication_output_accuracy: 0.9869 - content_output_accuracy: 0.9444 - val_loss: 0.1603 - val_sonication_output_loss: 0.0917 - val_content_output_loss: 0.2288 - val_sonication_output_accuracy: 0.9652 - val_content_output_accuracy: 0.9071
# Epoch 59/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1023 - sonication_output_loss: 0.0472 - content_output_loss: 0.1573 - sonication_output_accuracy: 0.9814 - content_output_accuracy: 0.9398
# Epoch 59: val_loss did not improve from 0.15237
# 122/122 [==============================] - 5s 37ms/step - loss: 0.1022 - sonication_output_loss: 0.0472 - content_output_loss: 0.1573 - sonication_output_accuracy: 0.9813 - content_output_accuracy: 0.9398 - val_loss: 0.1703 - val_sonication_output_loss: 0.0860 - val_content_output_loss: 0.2546 - val_sonication_output_accuracy: 0.9681 - val_content_output_accuracy: 0.9042
# Epoch 60/200
# 121/122 [============================>.] - ETA: 0s - loss: 0.1064 - sonication_output_loss: 0.0484 - content_output_loss: 0.1645 - sonication_output_accuracy: 0.9809 - content_output_accuracy: 0.9329
# Epoch 60: val_loss did not improve from 0.15237
# 122/122 [==============================] - 4s 36ms/step - loss: 0.1067 - sonication_output_loss: 0.0482 - content_output_loss: 0.1653 - sonication_output_accuracy: 0.9810 - content_output_accuracy: 0.9323 - val_loss: 0.1755 - val_sonication_output_loss: 0.0922 - val_content_output_loss: 0.2587 - val_sonication_output_accuracy: 0.9666 - val_content_output_accuracy: 0.8868
# Model saved at /content/drive/My Drive/Results/RGB/cnn_model.h5

# %% [markdown]
# ### Plot

# %%
# run_results는 fit 함수의 반환 값으로, 훈련의 히스토리 정보를 포함하고 있습니다.
history = run_results.history

# 손실 값 추출
train_loss = history['loss']
val_loss = history['val_loss']

# 에포크 번호
epochs = range(1, len(train_loss) + 1)
# 이동 평균을 계산하는 함수 정의
def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

# 이동 평균 윈도우 사이즈 설정
window_size = 5

# 이동 평균 계산
val_loss_ma = moving_average(val_loss, window_size)

# 유효한 이동 평균 데이터에 해당하는 에포크 번호 조정
valid_epochs = range(window_size, len(train_loss) + 1)
# 최소 검증 손실 값과 해당 인덱스 찾기
min_val_loss_index = np.argmin(val_loss)
min_val_loss = val_loss[min_val_loss_index]

# 손실 그래프 그리기
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', alpha=0.3, label='Validation loss')
plt.plot(valid_epochs, val_loss_ma, 'b', label='Validation loss (MA)')

# 최소 검증 손실 지점 표시
plt.plot(min_val_loss_index + 1, min_val_loss, 'ro', label='Minimum validation loss')

plt.title('Training and validation loss with Moving Average')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.savefig('/content/drive/My Drive/Results/RGB/training_curve.svg', format='svg')
plt.show()

# %%
# 저장된 모델을 불러옵니다.
# 모델 로드
model_path = "/content/drive/My Drive/Results/RGB/best_cnn_model.h5"

model = tf.keras.models.load_model(model_path)

# 모델을 사용하여 테스트 데이터에 대한 예측을 생성합니다.
predictions = model.predict(x_histo_test)

# 예측 결과를 분리합니다.
sonication_predictions, content_predictions = predictions



# 이진 분류 문제에 대한 지표를 계산합니다. (Sonication)
sonication_true = y_test_method
sonication_pred = (sonication_predictions > 0.5).astype(int)  # 시그모이드 출력을 이진 레이블로 변환

sonication_f1 = f1_score(sonication_true, sonication_pred)
sonication_precision = precision_score(sonication_true, sonication_pred)
sonication_recall = recall_score(sonication_true, sonication_pred)

# 다중 클래스 분류 문제에 대한 지표를 계산합니다. (Content)
content_true = np.argmax(y_test, axis=1)
content_pred = np.argmax(content_predictions, axis=1)

content_f1 = f1_score(content_true, content_pred, average='weighted')
content_precision = precision_score(content_true, content_pred, average='weighted')
content_recall = recall_score(content_true, content_pred, average='weighted')
print(sonication_f1, sonication_precision, sonication_recall)
print(content_f1, content_precision, content_recall)
sonication_cm = confusion_matrix(sonication_true, sonication_pred)
content_cm = confusion_matrix(content_true, content_pred)

# 혼동 행렬을 정규화합니다.
sonication_cm_norm = sonication_cm.astype('float') / sonication_cm.sum(axis=1)[:, np.newaxis]
content_cm_norm = content_cm.astype('float') / content_cm.sum(axis=1)[:, np.newaxis]

# 시각화를 위한 설정입니다.
fig, axs = plt.subplots(2, 2, figsize=(6.5, 6.5))


METHODS = ['Shear','Sonic']
CONTENTS = [0,0.05,0.1,0.2,0.4]
# KNN CONTENT 혼동 행렬을 시각화합니다.
sns.heatmap(sonication_cm_norm, annot=True, fmt=".2f", ax=axs[0, 0], cmap='Blues', xticklabels=METHODS, yticklabels=METHODS, vmin=0, vmax=1)
axs[0, 0].set_title('CNN Confusion Matrix')
axs[0, 0].set_xlabel('Predicted')
axs[0, 0].set_ylabel('True')

# KNN METHOD 혼동 행렬을 시각화합니다.
sns.heatmap(content_cm_norm, annot=True, fmt=".2f", ax=axs[0, 1], cmap='Blues', xticklabels=CONTENTS, yticklabels=CONTENTS, vmin=0, vmax=1)
axs[0, 1].set_title('CNN Confusion Matrix')
axs[0, 1].set_xlabel('Predicted')
axs[0, 1].set_ylabel('True')



plt.tight_layout()
plt.show()
# Out:
# 26/26 [==============================] - 0s 11ms/step
# 0.9739884393063584 0.9825072886297376 0.9656160458452722
# 0.9092233576293216 0.9100459470313679 0.908641975308642

# %%
fig.savefig('/content/drive/My Drive/Results/RGB/confusion_matrix.svg', format='svg')

# %% [markdown]
# # Time comparison according to data size

# %% [markdown]
# RGB Datatset, CNT content prediction

# %%
kernel_size = 7

filters = [64, 128, 256]

input_tensor = Input(shape=(256, 3))

x = Conv1D(filters=filters[0], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(input_tensor)
x = Dropout(0.2)(x)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=filters[1], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
x = Conv1D(filters=filters[1], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=filters[2], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
x = Conv1D(filters=filters[2], kernel_size=kernel_size, kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Dropout(0.2)(x)
x = MaxPooling1D(pool_size=2)(x)

flatten = Flatten()(x)
output = Dense(5, activation='softmax')(flatten)
cnn = Model(inputs=input_tensor, outputs=output)
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

cnn.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 3)]          0
#
#  conv1d (Conv1D)             (None, 256, 64)           1408
#
#  dropout (Dropout)           (None, 256, 64)           0
#
#  max_pooling1d (MaxPooling1D  (None, 128, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 128, 128)          57472
#
#  dropout_1 (Dropout)         (None, 128, 128)          0
#
#  conv1d_2 (Conv1D)           (None, 128, 128)          114816
#
#  dropout_2 (Dropout)         (None, 128, 128)          0
#
#  max_pooling1d_1 (MaxPooling  (None, 64, 128)          0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 64, 256)           229632
#
#  dropout_3 (Dropout)         (None, 64, 256)           0
#
#  conv1d_4 (Conv1D)           (None, 64, 256)           459008
#
#  dropout_4 (Dropout)         (None, 64, 256)           0
#
#  max_pooling1d_2 (MaxPooling  (None, 32, 256)          0
#  1D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 5)                 40965
#
# =================================================================
# Total params: 903,301
# Trainable params: 903,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
def model_comparison(ratio):
    idx = int(len(x_histo) * ratio)

    time_arr = []

    models = {
        'KNN': KNeighborsClassifier(metric='manhattan', n_neighbors=5, weights='distance'),
        'SVM': SVC(C=10, gamma='auto', kernel='rbf'),
        'RF': RandomForestClassifier(max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=200),
        'LGB': lgb.LGBMClassifier(max_depth=50, num_leaves=40),
        'CNN-1D': cnn
    }

    for model_name, model in models.items():
        if model_name in ['KNN', 'SVM']:
            pipe = Pipeline([
                ('scaler', StandardScaler()),
                (model_name.lower(), model)
            ])
            start_time = time.time()
            pipe.fit(x_histo[:idx], y_train[:idx].argmax(axis=1))
            end_time = time.time()
            accuracy = accuracy_score(y_test.argmax(axis=1), pipe.predict(x_histo_test))

        elif model_name in ['RF', 'LGB']:
            start_time = time.time()
            model.fit(x_histo[:idx], y_train[:idx].argmax(axis=1))
            end_time = time.time()
            accuracy = accuracy_score(y_test.argmax(axis=1), model.predict(x_histo_test))

        elif model_name == 'CNN-1D':
            early_stopping_callback = EarlyStopping(patience=20)

            start_time = time.time()
            history = model.fit(x_histo_train[:idx], y_train[:idx], validation_split=0.15,
                                batch_size=32, epochs=200,
                                callbacks=[early_stopping_callback])
            end_time = time.time()

            x_histo_test_reshape = x_histo_test.reshape(-1, 256, 3)
            predictions = model.predict(x_histo_test_reshape)
            accuracy = accuracy_score(y_test.argmax(axis=1), np.argmax(predictions, axis=1))

        # Output the results
        timestemp = end_time - start_time
        time_arr.append((model_name, timestemp, accuracy))  # Save model name and time to array

        print(f"Test accuracy for CONTENT with default {model_name} parameters: {accuracy}")
        print(f"{model_name} runtime: {timestemp} seconds")

    return time_arr

# %%
dataset50 = model_comparison(0.5)
# Out:
# Test accuracy for CONTENT with default KNN parameters: 0.8641975308641975
# KNN runtime: 0.06609225273132324 seconds
# Test accuracy for CONTENT with default SVM parameters: 0.8814814814814815
# SVM runtime: 0.7001893520355225 seconds
# Test accuracy for CONTENT with default RF parameters: 0.8987654320987655
# RF runtime: 4.130162477493286 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039255 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 117616
# [LightGBM] [Info] Number of data points in the train set: 2295, number of used features: 610
# [LightGBM] [Info] Start training from score -2.173968
# [LightGBM] [Info] Start training from score -1.527888
# [LightGBM] [Info] Start training from score -1.575173
# [LightGBM] [Info] Start training from score -1.445069
# [LightGBM] [Info] Start training from score -1.484659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Test accuracy for CONTENT with default LGB parameters: 0.9135802469135802
# LGB runtime: 4.049112558364868 seconds
# Epoch 1/200
# 61/61 [==============================] - 4s 42ms/step - loss: 0.9786 - accuracy: 0.5349 - val_loss: 0.8495 - val_accuracy: 0.5362
# Epoch 2/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.6764 - accuracy: 0.7072 - val_loss: 0.6747 - val_accuracy: 0.7565
# Epoch 3/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.5214 - accuracy: 0.8026 - val_loss: 0.5256 - val_accuracy: 0.8029
# Epoch 4/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.4580 - accuracy: 0.8195 - val_loss: 0.5145 - val_accuracy: 0.8116
# Epoch 5/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.4317 - accuracy: 0.8303 - val_loss: 0.4384 - val_accuracy: 0.8290
# Epoch 6/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.4097 - accuracy: 0.8292 - val_loss: 0.5114 - val_accuracy: 0.7826
# Epoch 7/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.3925 - accuracy: 0.8400 - val_loss: 0.4492 - val_accuracy: 0.8116
# Epoch 8/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.3822 - accuracy: 0.8426 - val_loss: 0.4360 - val_accuracy: 0.8058
# Epoch 9/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.3572 - accuracy: 0.8482 - val_loss: 0.4187 - val_accuracy: 0.8261
# Epoch 10/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.3473 - accuracy: 0.8564 - val_loss: 0.4467 - val_accuracy: 0.8116
# Epoch 11/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.3115 - accuracy: 0.8764 - val_loss: 0.3973 - val_accuracy: 0.8464
# Epoch 12/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.3237 - accuracy: 0.8687 - val_loss: 0.3633 - val_accuracy: 0.8580
# Epoch 13/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.3036 - accuracy: 0.8738 - val_loss: 0.4013 - val_accuracy: 0.8464
# Epoch 14/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.3150 - accuracy: 0.8697 - val_loss: 0.3582 - val_accuracy: 0.8522
# Epoch 15/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.3336 - accuracy: 0.8697 - val_loss: 0.3981 - val_accuracy: 0.8406
# Epoch 16/200
# 61/61 [==============================] - 2s 38ms/step - loss: 0.3294 - accuracy: 0.8641 - val_loss: 0.3593 - val_accuracy: 0.8464
# Epoch 17/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2721 - accuracy: 0.8923 - val_loss: 0.3713 - val_accuracy: 0.8493
# Epoch 18/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2719 - accuracy: 0.8867 - val_loss: 0.3074 - val_accuracy: 0.8754
# Epoch 19/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2667 - accuracy: 0.8872 - val_loss: 0.3561 - val_accuracy: 0.8435
# Epoch 20/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2605 - accuracy: 0.8867 - val_loss: 0.3416 - val_accuracy: 0.8696
# Epoch 21/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2569 - accuracy: 0.8979 - val_loss: 0.3237 - val_accuracy: 0.8754
# Epoch 22/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2372 - accuracy: 0.8969 - val_loss: 0.3166 - val_accuracy: 0.8696
# Epoch 23/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2453 - accuracy: 0.8974 - val_loss: 0.3119 - val_accuracy: 0.8783
# Epoch 24/200
# 61/61 [==============================] - 2s 38ms/step - loss: 0.2609 - accuracy: 0.8995 - val_loss: 0.3521 - val_accuracy: 0.8580
# Epoch 25/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2485 - accuracy: 0.8974 - val_loss: 0.3587 - val_accuracy: 0.8522
# Epoch 26/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2172 - accuracy: 0.9046 - val_loss: 0.3702 - val_accuracy: 0.8435
# Epoch 27/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2752 - accuracy: 0.8769 - val_loss: 0.3562 - val_accuracy: 0.8638
# Epoch 28/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2392 - accuracy: 0.8969 - val_loss: 0.3348 - val_accuracy: 0.8522
# Epoch 29/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2339 - accuracy: 0.9097 - val_loss: 0.2948 - val_accuracy: 0.8783
# Epoch 30/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2521 - accuracy: 0.9000 - val_loss: 0.3367 - val_accuracy: 0.8783
# Epoch 31/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2220 - accuracy: 0.9113 - val_loss: 0.3262 - val_accuracy: 0.8667
# Epoch 32/200
# 61/61 [==============================] - 2s 40ms/step - loss: 0.2172 - accuracy: 0.9087 - val_loss: 0.2905 - val_accuracy: 0.8812
# Epoch 33/200
# 61/61 [==============================] - 2s 38ms/step - loss: 0.2219 - accuracy: 0.9123 - val_loss: 0.4135 - val_accuracy: 0.8348
# Epoch 34/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2255 - accuracy: 0.9051 - val_loss: 0.3283 - val_accuracy: 0.8841
# Epoch 35/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2028 - accuracy: 0.9144 - val_loss: 0.2851 - val_accuracy: 0.8667
# Epoch 36/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1970 - accuracy: 0.9190 - val_loss: 0.2784 - val_accuracy: 0.8957
# Epoch 37/200
# 61/61 [==============================] - 2s 35ms/step - loss: 0.2159 - accuracy: 0.9051 - val_loss: 0.2862 - val_accuracy: 0.8812
# Epoch 38/200
# 61/61 [==============================] - 2s 35ms/step - loss: 0.2005 - accuracy: 0.9154 - val_loss: 0.3328 - val_accuracy: 0.8493
# Epoch 39/200
# 61/61 [==============================] - 2s 35ms/step - loss: 0.1910 - accuracy: 0.9185 - val_loss: 0.2867 - val_accuracy: 0.8841
# Epoch 40/200
# 61/61 [==============================] - 2s 35ms/step - loss: 0.2044 - accuracy: 0.9103 - val_loss: 0.3214 - val_accuracy: 0.8580
# Epoch 41/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2058 - accuracy: 0.9159 - val_loss: 0.2724 - val_accuracy: 0.8812
# Epoch 42/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1856 - accuracy: 0.9246 - val_loss: 0.2714 - val_accuracy: 0.8841
# Epoch 43/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2015 - accuracy: 0.9159 - val_loss: 0.2897 - val_accuracy: 0.8754
# Epoch 44/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1735 - accuracy: 0.9303 - val_loss: 0.2504 - val_accuracy: 0.9072
# Epoch 45/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1895 - accuracy: 0.9262 - val_loss: 0.3094 - val_accuracy: 0.8812
# Epoch 46/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1896 - accuracy: 0.9262 - val_loss: 0.2845 - val_accuracy: 0.8725
# Epoch 47/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1719 - accuracy: 0.9282 - val_loss: 0.2557 - val_accuracy: 0.8783
# Epoch 48/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1772 - accuracy: 0.9241 - val_loss: 0.2701 - val_accuracy: 0.8725
# Epoch 49/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1665 - accuracy: 0.9349 - val_loss: 0.3388 - val_accuracy: 0.8580
# Epoch 50/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1773 - accuracy: 0.9333 - val_loss: 0.2645 - val_accuracy: 0.8783
# Epoch 51/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1636 - accuracy: 0.9313 - val_loss: 0.2687 - val_accuracy: 0.8754
# Epoch 52/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1867 - accuracy: 0.9195 - val_loss: 0.2882 - val_accuracy: 0.8696
# Epoch 53/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1772 - accuracy: 0.9246 - val_loss: 0.3212 - val_accuracy: 0.8609
# Epoch 54/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1622 - accuracy: 0.9359 - val_loss: 0.2388 - val_accuracy: 0.8899
# Epoch 55/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1701 - accuracy: 0.9344 - val_loss: 0.2459 - val_accuracy: 0.8870
# Epoch 56/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1499 - accuracy: 0.9354 - val_loss: 0.2812 - val_accuracy: 0.8841
# Epoch 57/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1537 - accuracy: 0.9364 - val_loss: 0.2841 - val_accuracy: 0.8754
# Epoch 58/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1370 - accuracy: 0.9395 - val_loss: 0.3179 - val_accuracy: 0.8696
# Epoch 59/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1747 - accuracy: 0.9303 - val_loss: 0.2955 - val_accuracy: 0.8754
# Epoch 60/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1571 - accuracy: 0.9344 - val_loss: 0.2823 - val_accuracy: 0.8754
# Epoch 61/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1486 - accuracy: 0.9333 - val_loss: 0.2831 - val_accuracy: 0.8841
# Epoch 62/200
# 61/61 [==============================] - 2s 38ms/step - loss: 0.1758 - accuracy: 0.9303 - val_loss: 0.2825 - val_accuracy: 0.8899
# Epoch 63/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1743 - accuracy: 0.9267 - val_loss: 0.3043 - val_accuracy: 0.8783
# Epoch 64/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1657 - accuracy: 0.9287 - val_loss: 0.2715 - val_accuracy: 0.8841
# Epoch 65/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1578 - accuracy: 0.9385 - val_loss: 0.2605 - val_accuracy: 0.8783
# Epoch 66/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1625 - accuracy: 0.9241 - val_loss: 0.2663 - val_accuracy: 0.8754
# Epoch 67/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1371 - accuracy: 0.9426 - val_loss: 0.2697 - val_accuracy: 0.8841
# Epoch 68/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1322 - accuracy: 0.9441 - val_loss: 0.2522 - val_accuracy: 0.9014
# Epoch 69/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1943 - accuracy: 0.9251 - val_loss: 0.2594 - val_accuracy: 0.8841
# Epoch 70/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1541 - accuracy: 0.9359 - val_loss: 0.2786 - val_accuracy: 0.8957
# Epoch 71/200
# 61/61 [==============================] - 2s 37ms/step - loss: 0.1263 - accuracy: 0.9477 - val_loss: 0.2797 - val_accuracy: 0.8783
# Epoch 72/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1415 - accuracy: 0.9431 - val_loss: 0.3081 - val_accuracy: 0.8696
# Epoch 73/200
# 61/61 [==============================] - 2s 36ms/step - loss: 0.1332 - accuracy: 0.9446 - val_loss: 0.3160 - val_accuracy: 0.8812
# Epoch 74/200
# 61/61 [==============================] - 2s 35ms/step - loss: 0.1483 - accuracy: 0.9415 - val_loss: 0.2917 - val_accuracy: 0.8667
# 26/26 [==============================] - 0s 9ms/step
# Test accuracy for CONTENT with default CNN-1D parameters: 0.9
# CNN-1D runtime: 167.16385412216187 seconds

# %%
dataset50
# Out:
# [('KNN', 0.06609225273132324, 0.8641975308641975),
#  ('SVM', 0.7001893520355225, 0.8814814814814815),
#  ('RF', 4.130162477493286, 0.8987654320987655),
#  ('LGB', 4.049112558364868, 0.9135802469135802),
#  ('CNN-1D', 167.16385412216187, 0.9)]

# %%
dataset75 = model_comparison(0.75)
# Out:
# Test accuracy for CONTENT with default KNN parameters: 0.8790123456790123
# KNN runtime: 0.08997631072998047 seconds
# Test accuracy for CONTENT with default SVM parameters: 0.8925925925925926
# SVM runtime: 1.4019951820373535 seconds
# Test accuracy for CONTENT with default RF parameters: 0.9037037037037037
# RF runtime: 6.556934356689453 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 119728
# [LightGBM] [Info] Number of data points in the train set: 3442, number of used features: 623
# [LightGBM] [Info] Start training from score -2.187971
# [LightGBM] [Info] Start training from score -1.509175
# [LightGBM] [Info] Start training from score -1.538510
# [LightGBM] [Info] Start training from score -1.488368
# [LightGBM] [Info] Start training from score -1.485797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Test accuracy for CONTENT with default LGB parameters: 0.9135802469135802
# LGB runtime: 4.2048728466033936 seconds
# Epoch 1/200
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2102 - accuracy: 0.9169 - val_loss: 0.3088 - val_accuracy: 0.8917
# Epoch 2/200
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1948 - accuracy: 0.9248 - val_loss: 0.3239 - val_accuracy: 0.9014
# Epoch 3/200
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1949 - accuracy: 0.9268 - val_loss: 0.2803 - val_accuracy: 0.8878
# Epoch 4/200
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1821 - accuracy: 0.9262 - val_loss: 0.3037 - val_accuracy: 0.8781
# Epoch 5/200
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1666 - accuracy: 0.9344 - val_loss: 0.2801 - val_accuracy: 0.9014
# Epoch 6/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1646 - accuracy: 0.9326 - val_loss: 0.3338 - val_accuracy: 0.8646
# Epoch 7/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1716 - accuracy: 0.9289 - val_loss: 0.2848 - val_accuracy: 0.8975
# Epoch 8/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1696 - accuracy: 0.9282 - val_loss: 0.2770 - val_accuracy: 0.8801
# Epoch 9/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1533 - accuracy: 0.9350 - val_loss: 0.2711 - val_accuracy: 0.8936
# Epoch 10/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1547 - accuracy: 0.9364 - val_loss: 0.2657 - val_accuracy: 0.8936
# Epoch 11/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1613 - accuracy: 0.9337 - val_loss: 0.2975 - val_accuracy: 0.8878
# Epoch 12/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1548 - accuracy: 0.9357 - val_loss: 0.3154 - val_accuracy: 0.8743
# Epoch 13/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1753 - accuracy: 0.9282 - val_loss: 0.2991 - val_accuracy: 0.8781
# Epoch 14/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1404 - accuracy: 0.9381 - val_loss: 0.2805 - val_accuracy: 0.9014
# Epoch 15/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1594 - accuracy: 0.9323 - val_loss: 0.2898 - val_accuracy: 0.8859
# Epoch 16/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1418 - accuracy: 0.9415 - val_loss: 0.2739 - val_accuracy: 0.9014
# Epoch 17/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1410 - accuracy: 0.9391 - val_loss: 0.3409 - val_accuracy: 0.8781
# Epoch 18/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1554 - accuracy: 0.9354 - val_loss: 0.2769 - val_accuracy: 0.9072
# Epoch 19/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1278 - accuracy: 0.9521 - val_loss: 0.3076 - val_accuracy: 0.8956
# Epoch 20/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1328 - accuracy: 0.9443 - val_loss: 0.3078 - val_accuracy: 0.8762
# Epoch 21/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1375 - accuracy: 0.9484 - val_loss: 0.3126 - val_accuracy: 0.8762
# Epoch 22/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1304 - accuracy: 0.9487 - val_loss: 0.2660 - val_accuracy: 0.9072
# Epoch 23/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1259 - accuracy: 0.9487 - val_loss: 0.2975 - val_accuracy: 0.8956
# Epoch 24/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1193 - accuracy: 0.9535 - val_loss: 0.2464 - val_accuracy: 0.9149
# Epoch 25/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1290 - accuracy: 0.9470 - val_loss: 0.2729 - val_accuracy: 0.8956
# Epoch 26/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1156 - accuracy: 0.9562 - val_loss: 0.2952 - val_accuracy: 0.8839
# Epoch 27/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1261 - accuracy: 0.9569 - val_loss: 0.2744 - val_accuracy: 0.8975
# Epoch 28/200
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1670 - accuracy: 0.9350 - val_loss: 0.3310 - val_accuracy: 0.8665
# Epoch 29/200
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1333 - accuracy: 0.9446 - val_loss: 0.2733 - val_accuracy: 0.8897
# Epoch 30/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1211 - accuracy: 0.9521 - val_loss: 0.3026 - val_accuracy: 0.8820
# Epoch 31/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1134 - accuracy: 0.9559 - val_loss: 0.2790 - val_accuracy: 0.8917
# Epoch 32/200
# 92/92 [==============================] - 3s 34ms/step - loss: 0.1276 - accuracy: 0.9474 - val_loss: 0.2690 - val_accuracy: 0.8975
# Epoch 33/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1293 - accuracy: 0.9494 - val_loss: 0.2696 - val_accuracy: 0.8994
# Epoch 34/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1111 - accuracy: 0.9515 - val_loss: 0.2786 - val_accuracy: 0.9072
# Epoch 35/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1072 - accuracy: 0.9535 - val_loss: 0.2627 - val_accuracy: 0.8897
# Epoch 36/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1234 - accuracy: 0.9508 - val_loss: 0.3070 - val_accuracy: 0.8801
# Epoch 37/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1232 - accuracy: 0.9552 - val_loss: 0.2957 - val_accuracy: 0.8878
# Epoch 38/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1212 - accuracy: 0.9474 - val_loss: 0.3069 - val_accuracy: 0.8781
# Epoch 39/200
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1207 - accuracy: 0.9501 - val_loss: 0.3233 - val_accuracy: 0.8820
# Epoch 40/200
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1255 - accuracy: 0.9521 - val_loss: 0.3502 - val_accuracy: 0.8723
# Epoch 41/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1043 - accuracy: 0.9583 - val_loss: 0.2873 - val_accuracy: 0.8917
# Epoch 42/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.0963 - accuracy: 0.9593 - val_loss: 0.2877 - val_accuracy: 0.8917
# Epoch 43/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1125 - accuracy: 0.9559 - val_loss: 0.2633 - val_accuracy: 0.8956
# Epoch 44/200
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1141 - accuracy: 0.9593 - val_loss: 0.2944 - val_accuracy: 0.8917
# 26/26 [==============================] - 0s 9ms/step
# Test accuracy for CONTENT with default CNN-1D parameters: 0.9135802469135802
# CNN-1D runtime: 142.58223676681519 seconds

# %%
dataset75
# Out:
# [('KNN', 0.08997631072998047, 0.8790123456790123),
#  ('SVM', 1.4019951820373535, 0.8925925925925926),
#  ('RF', 6.556934356689453, 0.9037037037037037),
#  ('LGB', 4.2048728466033936, 0.9135802469135802),
#  ('CNN-1D', 142.58223676681519, 0.9135802469135802)]

# %%
datasetAll = model_comparison(1)
# Out:
# Test accuracy for CONTENT with default KNN parameters: 0.8753086419753087
# KNN runtime: 0.0661015510559082 seconds
# Test accuracy for CONTENT with default SVM parameters: 0.8938271604938272
# SVM runtime: 2.3013036251068115 seconds
# Test accuracy for CONTENT with default RF parameters: 0.9061728395061729
# RF runtime: 9.28799295425415 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055761 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 121384
# [LightGBM] [Info] Number of data points in the train set: 4590, number of used features: 630
# [LightGBM] [Info] Start training from score -2.207077
# [LightGBM] [Info] Start training from score -1.497238
# [LightGBM] [Info] Start training from score -1.520885
# [LightGBM] [Info] Start training from score -1.492381
# [LightGBM] [Info] Start training from score -1.501141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Test accuracy for CONTENT with default LGB parameters: 0.9234567901234568
# LGB runtime: 4.332196474075317 seconds
# Epoch 1/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1808 - accuracy: 0.9331 - val_loss: 0.2184 - val_accuracy: 0.9187
# Epoch 2/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1457 - accuracy: 0.9449 - val_loss: 0.2283 - val_accuracy: 0.9158
# Epoch 3/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1537 - accuracy: 0.9372 - val_loss: 0.1937 - val_accuracy: 0.9289
# Epoch 4/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1385 - accuracy: 0.9446 - val_loss: 0.2277 - val_accuracy: 0.9115
# Epoch 5/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1360 - accuracy: 0.9485 - val_loss: 0.2057 - val_accuracy: 0.9216
# Epoch 6/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1330 - accuracy: 0.9462 - val_loss: 0.2323 - val_accuracy: 0.9173
# Epoch 7/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1347 - accuracy: 0.9464 - val_loss: 0.2108 - val_accuracy: 0.9173
# Epoch 8/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1537 - accuracy: 0.9398 - val_loss: 0.2294 - val_accuracy: 0.8999
# Epoch 9/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1342 - accuracy: 0.9441 - val_loss: 0.2226 - val_accuracy: 0.9100
# Epoch 10/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1297 - accuracy: 0.9482 - val_loss: 0.2335 - val_accuracy: 0.9057
# Epoch 11/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1230 - accuracy: 0.9482 - val_loss: 0.2118 - val_accuracy: 0.9115
# Epoch 12/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1207 - accuracy: 0.9533 - val_loss: 0.2056 - val_accuracy: 0.9173
# Epoch 13/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1343 - accuracy: 0.9446 - val_loss: 0.2052 - val_accuracy: 0.9100
# Epoch 14/200
# 122/122 [==============================] - 4s 36ms/step - loss: 0.1348 - accuracy: 0.9451 - val_loss: 0.2326 - val_accuracy: 0.9057
# Epoch 15/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1083 - accuracy: 0.9590 - val_loss: 0.2189 - val_accuracy: 0.9173
# Epoch 16/200
# 122/122 [==============================] - 4s 34ms/step - loss: 0.1171 - accuracy: 0.9531 - val_loss: 0.2184 - val_accuracy: 0.9042
# Epoch 17/200
# 122/122 [==============================] - 4s 34ms/step - loss: 0.1324 - accuracy: 0.9480 - val_loss: 0.2234 - val_accuracy: 0.9086
# Epoch 18/200
# 122/122 [==============================] - 4s 34ms/step - loss: 0.1046 - accuracy: 0.9603 - val_loss: 0.2158 - val_accuracy: 0.9173
# Epoch 19/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1145 - accuracy: 0.9544 - val_loss: 0.2518 - val_accuracy: 0.9173
# Epoch 20/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1144 - accuracy: 0.9544 - val_loss: 0.2232 - val_accuracy: 0.9115
# Epoch 21/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.1161 - accuracy: 0.9521 - val_loss: 0.2082 - val_accuracy: 0.9231
# Epoch 22/200
# 122/122 [==============================] - 4s 36ms/step - loss: 0.1011 - accuracy: 0.9572 - val_loss: 0.2392 - val_accuracy: 0.9216
# Epoch 23/200
# 122/122 [==============================] - 4s 35ms/step - loss: 0.0974 - accuracy: 0.9610 - val_loss: 0.2417 - val_accuracy: 0.8984
# 26/26 [==============================] - 0s 9ms/step
# Test accuracy for CONTENT with default CNN-1D parameters: 0.8925925925925926
# CNN-1D runtime: 97.99575805664062 seconds

# %%
datasetAll
# Out:
# [('KNN', 0.0661015510559082, 0.8753086419753087),
#  ('SVM', 2.3013036251068115, 0.8938271604938272),
#  ('RF', 9.28799295425415, 0.9061728395061729),
#  ('LGB', 4.332196474075317, 0.9234567901234568),
#  ('CNN-1D', 97.99575805664062, 0.8925925925925926)]
